# %%
import pandas as pd 
df = pd.read_json('data/nobel_winners.json')
df.head()
# Out:
#                                                 link                    name  \
# 0  http://en.wikipedia.org/wiki/William_Lawrence_...  William Lawrence Bragg
# 1         http://en.wikipedia.org/wiki/Brian_Schmidt           Brian Schmidt
# 2   http://en.wikipedia.org/wiki/Elizabeth_Blackburn   Elizabeth Blackburn *
# 3        http://en.wikipedia.org/wiki/Barry_Marshall          Barry Marshall
# 4          http://en.wikipedia.org/wiki/Robin_Warren         J. Robin Warren
#
#    year                category    country    born_in  \
# 0  1915                 Physics  Australia
# 1  2011                 Physics  Australia
# 2  2009  Physiology or Medicine             Australia
# 3  2005  Physiology or Medicine  Australia
# 4  2005  Physiology or Medicine  Australia
#
#                                                 text      date_of_birth  \
# 0             William Lawrence Bragg , Physics, 1915      31 March 1890
# 1  Brian Schmidt ,  born in the United States , P...   24 February 1967
# 2  Elizabeth Blackburn *, Physiology or Medicine,...   26 November 1948
# 3      Barry Marshall , Physiology or Medicine, 2005  30 September 1951
# 4     J. Robin Warren , Physiology or Medicine, 2005       11 June 1937
#
#   date_of_death place_of_birth place_of_death  gender
# 0   1 July 1971       Adelaide        Ipswich    male
# 1           NaN       Missoula            NaN    male
# 2           NaN         Hobart            NaN  female
# 3           NaN     Kalgoorlie            NaN    male
# 4           NaN       Adelaide            NaN    male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1206 entries, 0 to 1205
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   link            1206 non-null   object
#  1   name            1206 non-null   object
#  2   year            1206 non-null   int64
#  3   category        1206 non-null   object
#  4   country         1206 non-null   object
#  5   born_in         1206 non-null   object
#  6   text            1206 non-null   object
#  7   date_of_birth   1197 non-null   object
#  8   date_of_death   824 non-null    object
#  9   place_of_birth  1197 non-null   object
#  10  place_of_death  821 non-null    object
#  11  gender          1197 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 113.2+ KB

# %%
df.describe()
# Out:
#               year
# count  1206.000000
# mean   1974.756219
# std      35.042148
# min    1809.000000
# 25%    1952.000000
# 50%    1980.000000
# 75%    2004.000000
# max    2023.000000

# %%
df.describe(include=['object'])
# Out:
#                                                link               name  \
# count                                          1206               1206
# unique                                          990               1125
# top     http://en.wikipedia.org/wiki/Charles_K._Kao  Vladimir Prelog *
# freq                                              4                  4
#
#                       category        country born_in  \
# count                     1206           1206    1206
# unique                       7             66      47
# top     Physiology or Medicine  United States
# freq                       283            408    1057
#
#                                                      text date_of_birth  \
# count                                                1206          1197
# unique                                               1184           952
# top     Leopold Ružička *,  Resided in what is now  Cr...  23 July 1906
# freq                                                    3             4
#
#             date_of_death place_of_birth place_of_death gender
# count                 824           1197            821   1197
# unique                663            683            357      2
# top     23 September 2018  New York City      Cambridge   male
# freq                    4             39             45   1113

# %%
df.columns
# Out:
# Index(['link', 'name', 'year', 'category', 'country', 'born_in', 'text',
#        'date_of_birth', 'date_of_death', 'place_of_birth', 'place_of_death',
#        'gender'],
#       dtype='object')

# %%
df = df.set_index('name')
df.head()
# Out:
#                                                                      link  \
# name
# William Lawrence Bragg  http://en.wikipedia.org/wiki/William_Lawrence_...
# Brian Schmidt                  http://en.wikipedia.org/wiki/Brian_Schmidt
# Elizabeth Blackburn *    http://en.wikipedia.org/wiki/Elizabeth_Blackburn
# Barry Marshall                http://en.wikipedia.org/wiki/Barry_Marshall
# J. Robin Warren                 http://en.wikipedia.org/wiki/Robin_Warren
#
#                         year                category    country    born_in  \
# name
# William Lawrence Bragg  1915                 Physics  Australia
# Brian Schmidt           2011                 Physics  Australia
# Elizabeth Blackburn *   2009  Physiology or Medicine             Australia
# Barry Marshall          2005  Physiology or Medicine  Australia
# J. Robin Warren         2005  Physiology or Medicine  Australia
#
#                                                                      text  \
# name
# William Lawrence Bragg             William Lawrence Bragg , Physics, 1915
# Brian Schmidt           Brian Schmidt ,  born in the United States , P...
# Elizabeth Blackburn *   Elizabeth Blackburn *, Physiology or Medicine,...
# Barry Marshall              Barry Marshall , Physiology or Medicine, 2005
# J. Robin Warren            J. Robin Warren , Physiology or Medicine, 2005
#
#                             date_of_birth date_of_death place_of_birth  \
# name
# William Lawrence Bragg      31 March 1890   1 July 1971       Adelaide
# Brian Schmidt            24 February 1967           NaN       Missoula
# Elizabeth Blackburn *    26 November 1948           NaN         Hobart
# Barry Marshall          30 September 1951           NaN     Kalgoorlie
# J. Robin Warren              11 June 1937           NaN       Adelaide
#
#                        place_of_death  gender
# name
# William Lawrence Bragg        Ipswich    male
# Brian Schmidt                     NaN    male
# Elizabeth Blackburn *             NaN  female
# Barry Marshall                    NaN    male
# J. Robin Warren                   NaN    male

# %%
df.head(2)
# Out:
#                                                                      link  \
# name
# William Lawrence Bragg  http://en.wikipedia.org/wiki/William_Lawrence_...
# Brian Schmidt                  http://en.wikipedia.org/wiki/Brian_Schmidt
#
#                         year category    country born_in  \
# name
# William Lawrence Bragg  1915  Physics  Australia
# Brian Schmidt           2011  Physics  Australia
#
#                                                                      text  \
# name
# William Lawrence Bragg             William Lawrence Bragg , Physics, 1915
# Brian Schmidt           Brian Schmidt ,  born in the United States , P...
#
#                            date_of_birth date_of_death place_of_birth  \
# name
# William Lawrence Bragg     31 March 1890   1 July 1971       Adelaide
# Brian Schmidt           24 February 1967           NaN       Missoula
#
#                        place_of_death gender
# name
# William Lawrence Bragg        Ipswich   male
# Brian Schmidt                     NaN   male

# %%
bi_col = df.born_in
bi_col
# Out:
# name
# William Lawrence Bragg
# Brian Schmidt
# Elizabeth Blackburn *     Australia
# Barry Marshall
# J. Robin Warren
#                             ...
# Peter Handke
# Martin Karplus *            Austria
# Elfriede Jelinek
# Eric Kandel *               Austria
# Walter Kohn *               Austria
# Name: born_in, Length: 1206, dtype: object

# %%
type(bi_col)
# Out:
# pandas.core.series.Series

# %%
df.iloc(0)

# %%
df = pd.read_json('data/nobel_winners.json')
df.set_index('name',inplace=True)
df.loc['Albert Einstein']
# Out:
#                                                          link  year category  \
# name
# Albert Einstein  http://en.wikipedia.org/wiki/Albert_Einstein  1921  Physics
# Albert Einstein  http://en.wikipedia.org/wiki/Albert_Einstein  1921  Physics
#
#                      country born_in  \
# name
# Albert Einstein  Switzerland
# Albert Einstein      Germany
#
#                                                               text  \
# name
# Albert Einstein  Albert Einstein ,  born in Germany , Physics, ...
# Albert Einstein                    Albert Einstein , Physics, 1921
#
#                  date_of_birth  date_of_death place_of_birth place_of_death  \
# name
# Albert Einstein  14 March 1879  18 April 1955            Ulm      Princeton
# Albert Einstein  14 March 1879  18 April 1955            Ulm      Princeton
#
#                 gender
# name
# Albert Einstein   male
# Albert Einstein   male

# %%
df = pd.read_json('data/nobel_winners.json')
df[0:10]
# Out:
#                                                 link                    name  \
# 0  http://en.wikipedia.org/wiki/William_Lawrence_...  William Lawrence Bragg
# 1         http://en.wikipedia.org/wiki/Brian_Schmidt           Brian Schmidt
# 2   http://en.wikipedia.org/wiki/Elizabeth_Blackburn   Elizabeth Blackburn *
# 3        http://en.wikipedia.org/wiki/Barry_Marshall          Barry Marshall
# 4          http://en.wikipedia.org/wiki/Robin_Warren         J. Robin Warren
# 5      http://en.wikipedia.org/wiki/Peter_C._Doherty        Peter C. Doherty
# 6      http://en.wikipedia.org/wiki/Rolf_Zinkernagel        Rolf Zinkernagel
# 7        http://en.wikipedia.org/wiki/John_Cornforth        John Cornforth *
# 8   http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein        César Milstein *
# 9  http://en.wikipedia.org/wiki/Adolfo_P%C3%A9rez...   Adolfo Pérez Esquivel
#
#    year                category    country    born_in  \
# 0  1915                 Physics  Australia
# 1  2011                 Physics  Australia
# 2  2009  Physiology or Medicine             Australia
# 3  2005  Physiology or Medicine  Australia
# 4  2005  Physiology or Medicine  Australia
# 5  1996  Physiology or Medicine  Australia
# 6  1996  Physiology or Medicine  Australia
# 7  1975               Chemistry             Australia
# 8  1984  Physiology or Medicine             Argentina
# 9  1980                   Peace  Argentina
#
#                                                 text      date_of_birth  \
# 0             William Lawrence Bragg , Physics, 1915      31 March 1890
# 1  Brian Schmidt ,  born in the United States , P...   24 February 1967
# 2  Elizabeth Blackburn *, Physiology or Medicine,...   26 November 1948
# 3      Barry Marshall , Physiology or Medicine, 2005  30 September 1951
# 4     J. Robin Warren , Physiology or Medicine, 2005       11 June 1937
# 5    Peter C. Doherty , Physiology or Medicine, 1996    15 October 1940
# 6    Rolf Zinkernagel , Physiology or Medicine, 1996     6 January 1944
# 7                  John Cornforth *, Chemistry, 1975   7 September 1917
# 8     César Milstein *, Physiology or Medicine, 1984     8 October 1927
# 9                Adolfo Pérez Esquivel , Peace, 1980   26 November 1931
#
#      date_of_death place_of_birth place_of_death  gender
# 0      1 July 1971       Adelaide        Ipswich    male
# 1              NaN       Missoula            NaN    male
# 2              NaN         Hobart            NaN  female
# 3              NaN     Kalgoorlie            NaN    male
# 4              NaN       Adelaide            NaN    male
# 5              NaN       Brisbane            NaN    male
# 6              NaN         Riehen            NaN    male
# 7  8 December 2013         Sydney       Brighton    male
# 8    24 March 2002   Bahía Blanca      Cambridge    male
# 9              NaN   Buenos Aires            NaN    male

# %%
df[-4:]
# Out:
#                                                link              name  year  \
# 1202    http://en.wikipedia.org/wiki/Martin_Karplus  Martin Karplus *  2013
# 1203  http://en.wikipedia.org/wiki/Elfriede_Jelinek  Elfriede Jelinek  2004
# 1204       http://en.wikipedia.org/wiki/Eric_Kandel     Eric Kandel *  2000
# 1205       http://en.wikipedia.org/wiki/Walter_Kohn     Walter Kohn *  1998
#
#                     category  country  born_in  \
# 1202               Chemistry           Austria
# 1203              Literature  Austria
# 1204  Physiology or Medicine           Austria
# 1205               Chemistry           Austria
#
#                                              text    date_of_birth  \
# 1202            Martin Karplus *, Chemistry, 2013    15 March 1930
# 1203          Elfriede Jelinek , Literature, 2004  20 October 1946
# 1204  Eric Kandel *, Physiology or Medicine, 2000  7 November 1929
# 1205               Walter Kohn *, Chemistry, 1998     9 March 1923
#
#       date_of_death place_of_birth place_of_death  gender
# 1202            NaN         Vienna            NaN    male
# 1203            NaN   Mürzzuschlag            NaN  female
# 1204            NaN         Vienna            NaN    male
# 1205  19 April 2016         Vienna  Santa Barbara    male

# %%
mask = df.year>2000
mask
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1201     True
# 1202     True
# 1203     True
# 1204    False
# 1205    False
# Name: year, Length: 1206, dtype: bool

# %%
mask = df.year > 2000
winners_since_2000 = df[mask]
winners_since_2000.count()
# Out:
# link              351
# name              351
# year              351
# category          351
# country           351
# born_in           351
# text              351
# date_of_birth     348
# date_of_death      75
# place_of_birth    348
# place_of_death     75
# gender            348
# dtype: int64

# %%
winners_since_2000.head()
# Out:
#                                                 link                   name  \
# 1         http://en.wikipedia.org/wiki/Brian_Schmidt          Brian Schmidt
# 2   http://en.wikipedia.org/wiki/Elizabeth_Blackburn  Elizabeth Blackburn *
# 3        http://en.wikipedia.org/wiki/Barry_Marshall         Barry Marshall
# 4          http://en.wikipedia.org/wiki/Robin_Warren        J. Robin Warren
# 14    http://en.wikipedia.org/wiki/Ardem_Patapoutian      Ardem Patapoutian
#
#     year                category    country    born_in  \
# 1   2011                 Physics  Australia
# 2   2009  Physiology or Medicine             Australia
# 3   2005  Physiology or Medicine  Australia
# 4   2005  Physiology or Medicine  Australia
# 14  2021  Physiology or Medicine    Armenia
#
#                                                  text      date_of_birth  \
# 1   Brian Schmidt ,  born in the United States , P...   24 February 1967
# 2   Elizabeth Blackburn *, Physiology or Medicine,...   26 November 1948
# 3       Barry Marshall , Physiology or Medicine, 2005  30 September 1951
# 4      J. Robin Warren , Physiology or Medicine, 2005       11 June 1937
# 14  Ardem Patapoutian ,  born in Lebanon , Physiol...     2 October 1967
#
#    date_of_death place_of_birth place_of_death  gender
# 1            NaN       Missoula            NaN    male
# 2            NaN         Hobart            NaN  female
# 3            NaN     Kalgoorlie            NaN    male
# 4            NaN       Adelaide            NaN    male
# 14           NaN         Beirut            NaN    male

# %%
winners_since_2000 = df[df.year > 2000]
winners_since_2000
# Out:
#                                                    link  \
# 1            http://en.wikipedia.org/wiki/Brian_Schmidt
# 2      http://en.wikipedia.org/wiki/Elizabeth_Blackburn
# 3           http://en.wikipedia.org/wiki/Barry_Marshall
# 4             http://en.wikipedia.org/wiki/Robin_Warren
# 14       http://en.wikipedia.org/wiki/Ardem_Patapoutian
# ...                                                 ...
# 1187  http://en.wikipedia.org/wiki/Fran%C3%A7ois_Eng...
# 1200       http://en.wikipedia.org/wiki/Anton_Zeilinger
# 1201          http://en.wikipedia.org/wiki/Peter_Handke
# 1202        http://en.wikipedia.org/wiki/Martin_Karplus
# 1203      http://en.wikipedia.org/wiki/Elfriede_Jelinek
#
#                        name  year                category    country  \
# 1             Brian Schmidt  2011                 Physics  Australia
# 2     Elizabeth Blackburn *  2009  Physiology or Medicine
# 3            Barry Marshall  2005  Physiology or Medicine  Australia
# 4           J. Robin Warren  2005  Physiology or Medicine  Australia
# 14        Ardem Patapoutian  2021  Physiology or Medicine    Armenia
# ...                     ...   ...                     ...        ...
# 1187       François Englert  2013                 Physics    Belgium
# 1200        Anton Zeilinger  2022                 Physics    Austria
# 1201           Peter Handke  2019              Literature    Austria
# 1202       Martin Karplus *  2013               Chemistry
# 1203       Elfriede Jelinek  2004              Literature    Austria
#
#         born_in                                               text  \
# 1                Brian Schmidt ,  born in the United States , P...
# 2     Australia  Elizabeth Blackburn *, Physiology or Medicine,...
# 3                    Barry Marshall , Physiology or Medicine, 2005
# 4                   J. Robin Warren , Physiology or Medicine, 2005
# 14               Ardem Patapoutian ,  born in Lebanon , Physiol...
# ...         ...                                                ...
# 1187                              François Englert , Physics, 2013
# 1200                               Anton Zeilinger , Physics, 2022
# 1201                               Peter Handke , Literature, 2019
# 1202    Austria                  Martin Karplus *, Chemistry, 2013
# 1203                           Elfriede Jelinek , Literature, 2004
#
#           date_of_birth date_of_death    place_of_birth place_of_death  gender
# 1      24 February 1967           NaN          Missoula            NaN    male
# 2      26 November 1948           NaN            Hobart            NaN  female
# 3     30 September 1951           NaN        Kalgoorlie            NaN    male
# 4          11 June 1937           NaN          Adelaide            NaN    male
# 14       2 October 1967           NaN            Beirut            NaN    male
# ...                 ...           ...               ...            ...     ...
# 1187    6 November 1932           NaN         Etterbeek            NaN    male
# 1200        20 May 1945           NaN  Ried im Innkreis            NaN    male
# 1201    6 December 1942           NaN           Griffen            NaN    male
# 1202      15 March 1930           NaN            Vienna            NaN    male
# 1203    20 October 1946           NaN      Mürzzuschlag            NaN  female
#
# [351 rows x 12 columns]

# %%
df.born_in.describe()
# Out:
# count     1206
# unique      47
# top
# freq      1057
# Name: born_in, dtype: object

# %%
set(df.born_in.apply(type))
# Out:
# {str}

# %%
import numpy as np

bi_col.replace("", np.nan, inplace=True)
bi_col
# Out:
# name
# William Lawrence Bragg          NaN
# Brian Schmidt                   NaN
# Elizabeth Blackburn *     Australia
# Barry Marshall                  NaN
# J. Robin Warren                 NaN
#                             ...
# Peter Handke                    NaN
# Martin Karplus *            Austria
# Elfriede Jelinek                NaN
# Eric Kandel *               Austria
# Walter Kohn *               Austria
# Name: born_in, Length: 1206, dtype: object

# %%
bi_col.count()
# Out:
# 149

# %%
df.replace('', np.nan, inplace=True)
df.head()
# Out:
#                                                 link                    name  \
# 0  http://en.wikipedia.org/wiki/William_Lawrence_...  William Lawrence Bragg
# 1         http://en.wikipedia.org/wiki/Brian_Schmidt           Brian Schmidt
# 2   http://en.wikipedia.org/wiki/Elizabeth_Blackburn   Elizabeth Blackburn *
# 3        http://en.wikipedia.org/wiki/Barry_Marshall          Barry Marshall
# 4          http://en.wikipedia.org/wiki/Robin_Warren         J. Robin Warren
#
#    year                category    country    born_in  \
# 0  1915                 Physics  Australia        NaN
# 1  2011                 Physics  Australia        NaN
# 2  2009  Physiology or Medicine        NaN  Australia
# 3  2005  Physiology or Medicine  Australia        NaN
# 4  2005  Physiology or Medicine  Australia        NaN
#
#                                                 text      date_of_birth  \
# 0             William Lawrence Bragg , Physics, 1915      31 March 1890
# 1  Brian Schmidt ,  born in the United States , P...   24 February 1967
# 2  Elizabeth Blackburn *, Physiology or Medicine,...   26 November 1948
# 3      Barry Marshall , Physiology or Medicine, 2005  30 September 1951
# 4     J. Robin Warren , Physiology or Medicine, 2005       11 June 1937
#
#   date_of_death place_of_birth place_of_death  gender
# 0   1 July 1971       Adelaide        Ipswich    male
# 1           NaN       Missoula            NaN    male
# 2           NaN         Hobart            NaN  female
# 3           NaN     Kalgoorlie            NaN    male
# 4           NaN       Adelaide            NaN    male

# %%
df[df.name.str.contains(r'\*')]['name']
# Out:
# 2       Elizabeth Blackburn *
# 7            John Cornforth *
# 8            César Milstein *
# 20         Baruj Benacerraf *
# 65              T. S. Eliot *
#                 ...
# 1191           Richard Kuhn *
# 1197        Karl von Frisch *
# 1202         Martin Karplus *
# 1204            Eric Kandel *
# 1205            Walter Kohn *
# Name: name, Length: 149, dtype: object

# %%
df.name = df.name.str.replace('*','',regex=True)
df.name = df.name.str.strip()
df[df.name.str.contains('\*')]
# Out:
# Empty DataFrame
# Columns: [link, name, year, category, country, born_in, text, date_of_birth, date_of_death, place_of_birth, place_of_death, gender]
# Index: []

# %%
# removing rows

np.nan == np.nan
# Out:
# False

# %%
df = df[df.born_in.isnull()]
df.count()
# Out:
# link              1057
# name              1057
# year              1057
# category          1056
# country           1057
# born_in              0
# text              1057
# date_of_birth     1048
# date_of_death      714
# place_of_birth    1048
# place_of_death     711
# gender            1048
# dtype: int64

# %%
df = df.drop("born_in", axis=1)
df.head()
# Out:
#                                                 link                    name  \
# 0  http://en.wikipedia.org/wiki/William_Lawrence_...  William Lawrence Bragg
# 1         http://en.wikipedia.org/wiki/Brian_Schmidt           Brian Schmidt
# 3        http://en.wikipedia.org/wiki/Barry_Marshall          Barry Marshall
# 4          http://en.wikipedia.org/wiki/Robin_Warren         J. Robin Warren
# 5      http://en.wikipedia.org/wiki/Peter_C._Doherty        Peter C. Doherty
#
#    year                category    country  \
# 0  1915                 Physics  Australia
# 1  2011                 Physics  Australia
# 3  2005  Physiology or Medicine  Australia
# 4  2005  Physiology or Medicine  Australia
# 5  1996  Physiology or Medicine  Australia
#
#                                                 text      date_of_birth  \
# 0             William Lawrence Bragg , Physics, 1915      31 March 1890
# 1  Brian Schmidt ,  born in the United States , P...   24 February 1967
# 3      Barry Marshall , Physiology or Medicine, 2005  30 September 1951
# 4     J. Robin Warren , Physiology or Medicine, 2005       11 June 1937
# 5    Peter C. Doherty , Physiology or Medicine, 1996    15 October 1940
#
#   date_of_death place_of_birth place_of_death gender
# 0   1 July 1971       Adelaide        Ipswich   male
# 1           NaN       Missoula            NaN   male
# 3           NaN     Kalgoorlie            NaN   male
# 4           NaN       Adelaide            NaN   male
# 5           NaN       Brisbane            NaN   male

# %%
# Finding Duplicates

dupes_by_name = df[df.duplicated('name')]
dupes_by_name.count()
# Out:
# link              70
# name              70
# year              70
# category          70
# country           70
# text              70
# date_of_birth     70
# date_of_death     35
# place_of_birth    70
# place_of_death    35
# gender            70
# dtype: int64

# %%
all_dupes = df[df.duplicated("name") | df.duplicated("name", keep="last")]
all_dupes.count()
# Out:
# link              136
# name              136
# year              136
# category          136
# country           136
# text              136
# date_of_birth     136
# date_of_death      69
# place_of_birth    136
# place_of_death     69
# gender            136
# dtype: int64

# %%
all_dupes = df[df.name.isin(dupes_by_name.name)]
all_dupes.count()
# Out:
# link              136
# name              136
# year              136
# category          136
# country           136
# text              136
# date_of_birth     136
# date_of_death      69
# place_of_birth    136
# place_of_death     69
# gender            136
# dtype: int64

# %%
for name,rows in df.groupby('name'):
    print(f'name: {name}, number of rows: {len(rows)}')
# Out:
# name: 14th Dalai Lama, number of rows: 1
# name: A. Michael Spence, number of rows: 1
# name: Aage Bohr, number of rows: 1
# name: Aaron Ciechanover, number of rows: 1
# name: Aaron Klug, number of rows: 1
# name: Abdulrazak Gurnah, number of rows: 1
# name: Abdus Salam, number of rows: 1
# name: Abhijit Banerjee, number of rows: 1
# name: Abiy Ahmed Ali, number of rows: 1
# name: Ada Yonath, number of rows: 1
# name: Adam G. Riess, number of rows: 1
# name: Adolf Butenandt, number of rows: 1
# name: Adolf Otto Reinhold Windaus, number of rows: 1
# name: Adolf von Baeyer, number of rows: 1
# name: Adolfo Pérez Esquivel, number of rows: 1
# name: Ahmed H. Zewail, number of rows: 1
# name: Ahmed Zewail, number of rows: 1
# name: Akira Suzuki, number of rows: 1
# name: Akira Yoshino, number of rows: 1
# name: Al Gore, number of rows: 1
# name: Alain Aspect, number of rows: 1
# name: Alan Heeger, number of rows: 1
# name: Alan Lloyd Hodgkin, number of rows: 1
# name: Alan MacDiarmid, number of rows: 2
# name: Albert A. Michelson, number of rows: 1
# name: Albert Camus, number of rows: 1
# name: Albert Claude, number of rows: 1
# name: Albert Einstein, number of rows: 2
# name: Albert Fert, number of rows: 1
# name: Albert Lutuli, number of rows: 1
# name: Albert Schweitzer, number of rows: 1
# name: Albert Szent-Györgyi, number of rows: 1
# name: Albrecht Kossel, number of rows: 1
# name: Aleksandr M. Prokhorov, number of rows: 1
# name: Aleksandr Solzhenitsyn, number of rows: 1
# name: Ales Bialiatski, number of rows: 1
# name: Alexander Fleming, number of rows: 1
# name: Alexander Prokhorov, number of rows: 1
# name: Alexander R. Todd, number of rows: 1
# name: Alexei Alexeyevich Abrikosov, number of rows: 1
# name: Alexei Ekimov, number of rows: 2
# name: Alexis Carrel, number of rows: 1
# name: Alfonso García Robles, number of rows: 1
# name: Alfred G. Gilman, number of rows: 1
# name: Alfred Hermann Fried, number of rows: 1
# name: Alfred Hershey, number of rows: 1
# name: Alfred Kastler, number of rows: 1
# name: Alfred Werner, number of rows: 1
# name: Alice Munro, number of rows: 1
# name: Allan M. Cormack, number of rows: 1
# name: Allvar Gullstrand, number of rows: 1
# name: Alva Myrdal, number of rows: 1
# name: Alvin E. Roth, number of rows: 1
# name: Amartya Sen, number of rows: 1
# name: American Friends Service Committee  (The Quakers), number of rows: 1
# name: Amnesty International, number of rows: 1
# name: Anatole France, number of rows: 1
# name: Andre Geim, number of rows: 1
# name: Andrea Ghez, number of rows: 1
# name: Andrei Sakharov, number of rows: 1
# name: Andrew Huxley, number of rows: 1
# name: Andrew Schally, number of rows: 1
# name: Andrew Z. Fire, number of rows: 1
# name: André F. Cournand, number of rows: 1
# name: André Frédéric Cournand, number of rows: 1
# name: André Gide, number of rows: 1
# name: André Lwoff, number of rows: 1
# name: Angus Deaton, number of rows: 2
# name: Anne L'Huillier, number of rows: 2
# name: Annie Ernaux, number of rows: 1
# name: Anthony J. Leggett, number of rows: 1
# name: Antoine Henri Becquerel, number of rows: 1
# name: Anton Zeilinger, number of rows: 1
# name: Antony Hewish, number of rows: 1
# name: António Egas Moniz, number of rows: 1
# name: Anwar Sadat, number of rows: 1
# name: Archer John Porter Martin, number of rows: 1
# name: Archibald Vivian Hill, number of rows: 1
# name: Ardem Patapoutian, number of rows: 2
# name: Arieh Warshel, number of rows: 2
# name: Aristide Briand, number of rows: 1
# name: Arne Tiselius, number of rows: 1
# name: Arno Penzias, number of rows: 1
# name: Arthur Ashkin, number of rows: 1
# name: Arthur B. McDonald, number of rows: 1
# name: Arthur H. Compton, number of rows: 1
# name: Arthur Harden, number of rows: 1
# name: Arthur Henderson, number of rows: 1
# name: Arthur Kornberg, number of rows: 1
# name: Arthur L. Schawlow, number of rows: 1
# name: Artturi Ilmari Virtanen, number of rows: 1
# name: Arvid Carlsson, number of rows: 1
# name: August Krogh, number of rows: 1
# name: Auguste Beernaert, number of rows: 1
# name: Aung San Suu Kyi, number of rows: 1
# name: Austen Chamberlain, number of rows: 1
# name: Avram Hershko, number of rows: 1
# name: Aziz Sancar, number of rows: 2
# name: Barack H. Obama, number of rows: 1
# name: Barbara McClintock, number of rows: 1
# name: Barry Barish, number of rows: 1
# name: Barry Marshall, number of rows: 1
# name: Baruch S. Blumberg, number of rows: 1
# name: Baruj Benacerraf, number of rows: 1
# name: Ben Bernanke, number of rows: 1
# name: Ben Feringa, number of rows: 1
# name: Ben Roy Mottelson, number of rows: 1
# name: Bengt I. Samuelsson, number of rows: 1
# name: Bengt R. Holmström, number of rows: 1
# name: Benjamin List, number of rows: 1
# name: Bernard Katz, number of rows: 1
# name: Bernardo Houssay, number of rows: 1
# name: Bert Sakmann, number of rows: 1
# name: Bertha von Suttner, number of rows: 1
# name: Bertil Ohlin, number of rows: 1
# name: Bertram Brockhouse, number of rows: 1
# name: Bertrand Russell, number of rows: 1
# name: Betty Williams, number of rows: 2
# name: Bjørnstjerne Bjørnson, number of rows: 1
# name: Bob Dylan, number of rows: 1
# name: Boris Pasternak, number of rows: 1
# name: Brian David Josephson, number of rows: 1
# name: Brian K. Kobilka, number of rows: 1
# name: Brian P. Schmidt, number of rows: 1
# name: Brian Schmidt, number of rows: 1
# name: Bruce Beutler, number of rows: 1
# name: Bruce Merrifield, number of rows: 1
# name: Burton Richter, number of rows: 1
# name: C. V. Raman, number of rows: 1
# name: Camillo Golgi, number of rows: 1
# name: Camilo José Cela, number of rows: 1
# name: Carl Anderson, number of rows: 1
# name: Carl Bosch, number of rows: 1
# name: Carl E. Wieman, number of rows: 1
# name: Carl Ferdinand Cori, number of rows: 2
# name: Carl Gustaf Verner von Heidenstam, number of rows: 1
# name: Carl Spitteler, number of rows: 1
# name: Carl von Ossietzky, number of rows: 1
# name: Carlo Rubbia, number of rows: 1
# name: Carlos Filipe Ximenes Belo, number of rows: 1
# name: Carlos Saavedra Lamas, number of rows: 1
# name: Carol W. Greider, number of rows: 1
# name: Carolyn R. Bertozzi, number of rows: 1
# name: Cecil Frank Powell, number of rows: 1
# name: Centre for Civil Liberties, number of rows: 1
# name: Charles Albert Gobat, number of rows: 1
# name: Charles B. Huggins, number of rows: 1
# name: Charles G. Dawes, number of rows: 1
# name: Charles Glover Barkla, number of rows: 1
# name: Charles H. Townes, number of rows: 1
# name: Charles J. Pedersen, number of rows: 1
# name: Charles K. Kao, number of rows: 3
# name: Charles Louis Alphonse Laveran, number of rows: 1
# name: Charles M. Rice, number of rows: 1
# name: Charles Nicolle, number of rows: 1
# name: Charles Richet, number of rows: 1
# name: Charles Scott Sherrington, number of rows: 1
# name: Charles Thomson Rees Wilson, number of rows: 1
# name: Charles Édouard Guillaume, number of rows: 1
# name: Chen Ning Yang, number of rows: 1
# name: Christiaan Eijkman, number of rows: 1
# name: Christian Anfinsen, number of rows: 1
# name: Christian Lous Lange, number of rows: 1
# name: Christian de Duve, number of rows: 1
# name: Christiane Nüsslein-Volhard, number of rows: 1
# name: Christopher A. Pissarides, number of rows: 1
# name: Christopher A. Sims, number of rows: 1
# name: Claude Cohen-Tannoudji, number of rows: 1
# name: Claude Simon, number of rows: 1
# name: Claudia Goldin, number of rows: 1
# name: Clifford G. Shull, number of rows: 1
# name: Clinton Davisson, number of rows: 1
# name: Clive W. J. Granger, number of rows: 1
# name: Cordell Hull, number of rows: 1
# name: Corneille Heymans, number of rows: 1
# name: Craig C. Mello, number of rows: 1
# name: Cyril Norman Hinshelwood, number of rows: 1
# name: Czesław Miłosz, number of rows: 1
# name: César Milstein, number of rows: 1
# name: Dag Hammarskjöld, number of rows: 1
# name: Dale T. Mortensen, number of rows: 1
# name: Dan Shechtman, number of rows: 1
# name: Daniel Bovet, number of rows: 2
# name: Daniel C. Tsui, number of rows: 1
# name: Daniel Carleton Gajdusek, number of rows: 1
# name: Daniel Kahneman, number of rows: 1
# name: Daniel L. McFadden, number of rows: 1
# name: Daniel Nathans, number of rows: 1
# name: Dario Fo, number of rows: 1
# name: David Baltimore, number of rows: 1
# name: David Card, number of rows: 2
# name: David H. Hubel, number of rows: 1
# name: David J. Gross, number of rows: 1
# name: David J. Thouless, number of rows: 1
# name: David J. Wineland, number of rows: 1
# name: David Julius, number of rows: 1
# name: David M. Lee, number of rows: 1
# name: David MacMillan, number of rows: 2
# name: David Trimble, number of rows: 2
# name: Denis Mukwege, number of rows: 1
# name: Dennis Gabor, number of rows: 1
# name: Derek Harold Richard Barton, number of rows: 1
# name: Derek Walcott, number of rows: 1
# name: Desmond Tutu, number of rows: 1
# name: Dickinson W. Richards, number of rows: 1
# name: Didier Queloz, number of rows: 1
# name: Dmitry Muratov, number of rows: 1
# name: Dominique Pire, number of rows: 1
# name: Donald A. Glaser, number of rows: 1
# name: Donald J. Cram, number of rows: 1
# name: Donna Strickland, number of rows: 1
# name: Doris Lessing, number of rows: 1
# name: Dorothy Crowfoot Hodgkin, number of rows: 1
# name: Douglas D. Osheroff, number of rows: 1
# name: Douglas Diamond, number of rows: 1
# name: Douglass C. North, number of rows: 1
# name: Drew Weissman, number of rows: 1
# name: Dudley R. Herschbach, number of rows: 1
# name: Dénes Gábor, number of rows: 1
# name: E. Donnall Thomas, number of rows: 1
# name: E. M. Purcell, number of rows: 1
# name: Earl W. Sutherland Jr., number of rows: 1
# name: Edgar Adrian, number of rows: 1
# name: Edmond H. Fischer, number of rows: 2
# name: Edmund S. Phelps, number of rows: 1
# name: Eduard Buchner, number of rows: 1
# name: Edvard Moser, number of rows: 1
# name: Edward A. Doisy, number of rows: 1
# name: Edward B. Lewis, number of rows: 1
# name: Edward C. Kendall, number of rows: 1
# name: Edward C. Prescott, number of rows: 1
# name: Edward Tatum, number of rows: 1
# name: Edward Victor Appleton, number of rows: 1
# name: Edwin G. Krebs, number of rows: 1
# name: Edwin M. McMillan, number of rows: 1
# name: Ei-ichi Negishi, number of rows: 2
# name: Eisaku Satō, number of rows: 1
# name: Elfriede Jelinek, number of rows: 1
# name: Elias Canetti, number of rows: 1
# name: Elias James Corey, number of rows: 1
# name: Elie Wiesel, number of rows: 1
# name: Elihu Root, number of rows: 1
# name: Elinor Ostrom, number of rows: 1
# name: Elizabeth Blackburn, number of rows: 1
# name: Ellen Johnson Sirleaf, number of rows: 1
# name: Emil Adolf von Behring, number of rows: 1
# name: Emilio Segrè, number of rows: 1
# name: Emily G. Balch, number of rows: 1
# name: Emmanuelle Charpentier, number of rows: 1
# name: Enrico Fermi, number of rows: 1
# name: Eric A. Cornell, number of rows: 1
# name: Eric Betzig, number of rows: 1
# name: Eric F. Wieschaus, number of rows: 1
# name: Eric Kandel, number of rows: 1
# name: Eric S. Maskin, number of rows: 1
# name: Erik Axel Karlfeldt, number of rows: 1
# name: Ernest Hemingway, number of rows: 1
# name: Ernest Lawrence, number of rows: 1
# name: Ernest Rutherford, number of rows: 1
# name: Ernest Walton, number of rows: 1
# name: Ernesto Teodoro Moneta, number of rows: 1
# name: Ernst Boris Chain, number of rows: 1
# name: Ernst Otto Fischer, number of rows: 1
# name: Ernst Ruska, number of rows: 1
# name: Erwin Neher, number of rows: 1
# name: Erwin Schrödinger, number of rows: 1
# name: Esther Duflo, number of rows: 2
# name: Eugene F. Fama, number of rows: 1
# name: Eugene O'Neill, number of rows: 1
# name: Eugene Wigner, number of rows: 1
# name: Eugenio Montale, number of rows: 1
# name: Eyvind Johnson, number of rows: 1
# name: F. Duncan M. Haldane, number of rows: 2
# name: F. Sherwood Rowland, number of rows: 1
# name: F. W. de Klerk, number of rows: 1
# name: Felix Bloch, number of rows: 2
# name: Feodor Felix Konrad Lynen, number of rows: 1
# name: Ferdinand Buisson, number of rows: 1
# name: Ferenc Krausz, number of rows: 1
# name: Ferid Murad, number of rows: 1
# name: Finn E. Kydland, number of rows: 1
# name: Frances Arnold, number of rows: 1
# name: Francis Crick, number of rows: 1
# name: Francis Peyton Rous, number of rows: 1
# name: Francis William Aston, number of rows: 1
# name: Franco Modigliani, number of rows: 1
# name: Frank B. Kellogg, number of rows: 1
# name: Frank Wilczek, number of rows: 1
# name: Frans Eemil Sillanpää, number of rows: 1
# name: François Englert, number of rows: 1
# name: François Jacob, number of rows: 1
# name: François Mauriac, number of rows: 1
# name: Françoise Barré-Sinoussi, number of rows: 1
# name: Fraser Stoddart, number of rows: 2
# name: Frederick Banting, number of rows: 1
# name: Frederick C. Robbins, number of rows: 1
# name: Frederick Hopkins, number of rows: 1
# name: Frederick Reines, number of rows: 1
# name: Frederick Sanger, number of rows: 2
# name: Frederick Soddy, number of rows: 1
# name: Fredrik Bajer, number of rows: 1
# name: Fridtjof Nansen, number of rows: 1
# name: Friedrich Bergius, number of rows: 1
# name: Friedrich Hayek, number of rows: 2
# name: Friends Service Council, number of rows: 1
# name: Frits Zernike, number of rows: 1
# name: Fritz Albert Lipmann, number of rows: 1
# name: Fritz Haber, number of rows: 1
# name: Fritz Pregl, number of rows: 1
# name: Frédéric Joliot-Curie, number of rows: 1
# name: Frédéric Mistral, number of rows: 1
# name: Frédéric Passy, number of rows: 1
# name: Fülöp Lénárd, number of rows: 1
# name: Gabriel García Márquez, number of rows: 1
# name: Gabriel Lippmann, number of rows: 1
# name: Gabriela Mistral, number of rows: 1
# name: Gao Xingjian, number of rows: 1
# name: Gary S. Becker, number of rows: 1
# name: Geoffrey Wilkinson, number of rows: 1
# name: Georg Wittig, number of rows: 1
# name: Georg von Békésy, number of rows: 1
# name: George A. Akerlof, number of rows: 1
# name: George Andrew Olah, number of rows: 1
# name: George Beadle, number of rows: 1
# name: George Bernard Shaw, number of rows: 1
# name: George C. Marshall, number of rows: 1
# name: George D. Snell, number of rows: 1
# name: George E. Palade, number of rows: 1
# name: George E. Smith, number of rows: 1
# name: George F. Smoot, number of rows: 1
# name: George H. Hitchings, number of rows: 1
# name: George H. Whipple, number of rows: 1
# name: George J. Stigler, number of rows: 1
# name: George P. Smith, number of rows: 1
# name: George Paget Thomson, number of rows: 1
# name: George Porter, number of rows: 1
# name: George R. Minot, number of rows: 1
# name: George Wald, number of rows: 1
# name: Georges Charpak, number of rows: 1
# name: Gerald Edelman, number of rows: 1
# name: Gerard 't Hooft, number of rows: 1
# name: Gerd Binnig, number of rows: 1
# name: Gerhard Domagk, number of rows: 1
# name: Gerhard Ertl, number of rows: 1
# name: Gerhard Herzberg, number of rows: 1
# name: Gerhart Hauptmann, number of rows: 1
# name: Gertrude B. Elion, number of rows: 1
# name: Gerty Cori, number of rows: 2
# name: Giorgio Parisi, number of rows: 1
# name: Giorgos Seferis, number of rows: 1
# name: Giosuè Carducci, number of rows: 1
# name: Giulio Natta, number of rows: 1
# name: Glenn Theodore Seaborg, number of rows: 1
# name: Godfrey Hounsfield, number of rows: 1
# name: Grazia Deledda, number of rows: 1
# name: Greg Winter, number of rows: 1
# name: Gregg L. Semenza, number of rows: 1
# name: Guglielmo Marconi, number of rows: 1
# name: Guido Imbens, number of rows: 2
# name: Gunnar Myrdal, number of rows: 1
# name: Gustaf Dalén, number of rows: 1
# name: Gustav Ludwig Hertz, number of rows: 1
# name: Gustav Stresemann, number of rows: 1
# name: György András Oláh, number of rows: 1
# name: György Békésy, number of rows: 1
# name: György Hevesy, number of rows: 1
# name: Gérard Debreu, number of rows: 2
# name: Gérard Mourou, number of rows: 1
# name: Günter Blobel, number of rows: 1
# name: Günter Grass, number of rows: 1
# name: H. David Politzer, number of rows: 1
# name: H. Robert Horvitz, number of rows: 1
# name: Haldan Keffer Hartline, number of rows: 1
# name: Halldór Laxness, number of rows: 1
# name: Hamilton O. Smith, number of rows: 1
# name: Hannes Alfvén, number of rows: 1
# name: Hans Adolf Krebs, number of rows: 1
# name: Hans Bethe, number of rows: 1
# name: Hans Fischer, number of rows: 1
# name: Hans G. Dehmelt, number of rows: 1
# name: Hans Spemann, number of rows: 1
# name: Hans von Euler-Chelpin, number of rows: 1
# name: Har Gobind Khorana, number of rows: 1
# name: Harald zur Hausen, number of rows: 1
# name: Harold C. Urey, number of rows: 1
# name: Harold E. Varmus, number of rows: 1
# name: Harold Kroto, number of rows: 1
# name: Harold Pinter, number of rows: 1
# name: Harry M. Markowitz, number of rows: 1
# name: Harry Martinson, number of rows: 1
# name: Hartmut Michel, number of rows: 1
# name: Harvey J. Alter, number of rows: 1
# name: Heike Kamerlingh Onnes, number of rows: 1
# name: Heinrich Böll, number of rows: 1
# name: Heinrich Otto Wieland, number of rows: 1
# name: Heinrich Rohrer, number of rows: 1
# name: Hendrik Lorentz, number of rows: 1
# name: Henri Bergson, number of rows: 1
# name: Henri La Fontaine, number of rows: 1
# name: Henri Moissan, number of rows: 1
# name: Henrik Dam, number of rows: 1
# name: Henrik Pontoppidan, number of rows: 1
# name: Henry Dunant, number of rows: 2
# name: Henry Hallett Dale, number of rows: 1
# name: Henry Kissinger, number of rows: 1
# name: Henry Taube, number of rows: 1
# name: Henry W. Kendall, number of rows: 1
# name: Henryk Sienkiewicz, number of rows: 1
# name: Herbert A. Hauptman, number of rows: 1
# name: Herbert A. Simon, number of rows: 1
# name: Herbert C. Brown, number of rows: 1
# name: Herbert Kroemer, number of rows: 1
# name: Herbert S. Gasser, number of rows: 1
# name: Hermann Emil Fischer, number of rows: 1
# name: Hermann Hesse, number of rows: 1
# name: Hermann J. Muller, number of rows: 1
# name: Hermann Staudinger, number of rows: 1
# name: Herta Müller, number of rows: 1
# name: Hideki Shirakawa, number of rows: 1
# name: Hideki Yukawa, number of rows: 1
# name: Hiroshi Amano, number of rows: 1
# name: Hjalmar Branting, number of rows: 1
# name: Horst L. Störmer, number of rows: 1
# name: Horst Ludwig Störmer, number of rows: 1
# name: Howard Florey, number of rows: 1
# name: Howard Martin Temin, number of rows: 1
# name: Hugo Theorell, number of rows: 1
# name: Igor Tamm, number of rows: 1
# name: Ilya Ilyich Mechnikov, number of rows: 1
# name: Ilya Mikhailovich Frank, number of rows: 1
# name: Ilya Prigogine, number of rows: 1
# name: Imre Kertész, number of rows: 1
# name: Institut de Droit International, number of rows: 1
# name: Irving Langmuir, number of rows: 1
# name: Irwin Rose, number of rows: 1
# name: Irène Joliot-Curie, number of rows: 1
# name: Isaac Bashevis Singer, number of rows: 1
# name: Isamu Akasaki, number of rows: 1
# name: Isidor Isaac Rabi, number of rows: 1
# name: Ivan Bunin, number of rows: 1
# name: Ivan Pavlov, number of rows: 1
# name: Ivar Giaever, number of rows: 2
# name: Ivo Andric, number of rows: 1
# name: Ivo Andrić, number of rows: 1
# name: J. Georg Bednorz, number of rows: 1
# name: J. Hans D. Jensen, number of rows: 1
# name: J. J. Thomson, number of rows: 1
# name: J. M. Coetzee, number of rows: 1
# name: J. M. G. Le Clézio, number of rows: 1
# name: J. Michael Bishop, number of rows: 1
# name: J. Robin Warren, number of rows: 1
# name: Jacinto Benavente, number of rows: 1
# name: Jack Kilby, number of rows: 1
# name: Jack Steinberger, number of rows: 1
# name: Jack W. Szostak, number of rows: 3
# name: Jacobus Henricus van 't Hoff, number of rows: 1
# name: Jacques Dubochet, number of rows: 1
# name: Jacques Monod, number of rows: 1
# name: James A. Mirrlees, number of rows: 1
# name: James Allison, number of rows: 1
# name: James B. Sumner, number of rows: 1
# name: James Chadwick, number of rows: 1
# name: James Cronin, number of rows: 1
# name: James D. Watson, number of rows: 1
# name: James Franck, number of rows: 1
# name: James J. Heckman, number of rows: 1
# name: James M. Buchanan, number of rows: 1
# name: James Meade, number of rows: 1
# name: James Rainwater, number of rows: 1
# name: James Rothman, number of rows: 1
# name: James Tobin, number of rows: 1
# name: James W. Black, number of rows: 1
# name: Jan Tinbergen, number of rows: 1
# name: Jane Addams, number of rows: 1
# name: Jaroslav Heyrovský, number of rows: 1
# name: Jaroslav Seifert, number of rows: 1
# name: Jean Baptiste Perrin, number of rows: 1
# name: Jean Dausset, number of rows: 1
# name: Jean Tirole, number of rows: 1
# name: Jean-Marie Lehn, number of rows: 1
# name: Jean-Paul Sartre, number of rows: 1
# name: Jean-Pierre Sauvage, number of rows: 1
# name: Jeffrey C. Hall, number of rows: 1
# name: Jennifer Doudna, number of rows: 1
# name: Jens Christian Skou, number of rows: 1
# name: Jenő Pál Wigner, number of rows: 1
# name: Jerome I. Friedman, number of rows: 1
# name: Jerome Karle, number of rows: 1
# name: Jim Peebles, number of rows: 2
# name: Jimmy Carter, number of rows: 1
# name: Joachim Frank, number of rows: 1
# name: Jody Williams, number of rows: 1
# name: Johann Deisenhofer, number of rows: 1
# name: Johannes Diderik van der Waals, number of rows: 1
# name: Johannes Fibiger, number of rows: 1
# name: Johannes Stark, number of rows: 1
# name: Johannes V. Jensen, number of rows: 1
# name: John B. Goodenough, number of rows: 1
# name: John B. Gurdon, number of rows: 1
# name: John Bardeen, number of rows: 2
# name: John Bennett Fenn, number of rows: 1
# name: John Boyd Orr, number of rows: 1
# name: John C. Mather, number of rows: 1
# name: John Carew Eccles, number of rows: 1
# name: John Clauser, number of rows: 1
# name: John Cockcroft, number of rows: 1
# name: John Cornforth, number of rows: 1
# name: John E. Sulston, number of rows: 1
# name: John E. Walker, number of rows: 1
# name: John F. Enders, number of rows: 1
# name: John Forbes Nash, number of rows: 1
# name: John Galsworthy, number of rows: 1
# name: John H. Northrop, number of rows: 1
# name: John H. van Vleck, number of rows: 1
# name: John Harsanyi, number of rows: 1
# name: John Hicks, number of rows: 1
# name: John Hume, number of rows: 1
# name: John Kendrew, number of rows: 1
# name: John L. Hall, number of rows: 1
# name: John M. Kosterlitz, number of rows: 2
# name: John Macleod, number of rows: 1
# name: John O'Keefe, number of rows: 1
# name: John Polanyi, number of rows: 1
# name: John Pople, number of rows: 1
# name: John R. Mott, number of rows: 1
# name: John Robert Vane, number of rows: 1
# name: John Steinbeck, number of rows: 1
# name: John Strutt, number of rows: 1
# name: Jon Fosse, number of rows: 1
# name: Joseph Brodsky, number of rows: 2
# name: Joseph E. Murray, number of rows: 1
# name: Joseph E. Stiglitz, number of rows: 1
# name: Joseph Erlanger, number of rows: 1
# name: Joseph H. Taylor Jr., number of rows: 1
# name: Joseph L. Goldstein, number of rows: 1
# name: Joseph Rotblat, number of rows: 1
# name: Joshua Angrist, number of rows: 2
# name: Joshua Lederberg, number of rows: 1
# name: José Echegaray, number of rows: 1
# name: José Ramos-Horta, number of rows: 1
# name: José Saramago, number of rows: 1
# name: Juan Manuel Santos Calderón, number of rows: 1
# name: Juan Ramón Jiménez, number of rows: 1
# name: Jules A. Hoffmann, number of rows: 1
# name: Jules Bordet, number of rows: 1
# name: Julian Schwinger, number of rows: 1
# name: Julius Axelrod, number of rows: 1
# name: Julius Wagner-Jauregg, number of rows: 1
# name: János Harsányi, number of rows: 1
# name: János Polányi, number of rows: 1
# name: K. Barry Sharpless, number of rows: 2
# name: Kai Siegbahn, number of rows: 1
# name: Kailash Satyarthi, number of rows: 1
# name: Karl Adolph Gjellerup, number of rows: 1
# name: Karl Alexander Müller, number of rows: 1
# name: Karl Ferdinand Braun, number of rows: 1
# name: Karl Landsteiner, number of rows: 1
# name: Karl Manne Siegbahn, number of rows: 1
# name: Karl Ziegler, number of rows: 1
# name: Karl von Frisch, number of rows: 1
# name: Kary B. Mullis, number of rows: 1
# name: Katalin Karikó, number of rows: 2
# name: Kazuo Ishiguro, number of rows: 1
# name: Kenichi Fukui, number of rows: 1
# name: Kenneth G. Wilson, number of rows: 1
# name: Kenneth J. Arrow, number of rows: 1
# name: Kenzaburō Ōe, number of rows: 1
# name: Kim Dae-jung, number of rows: 1
# name: Kip Thorne, number of rows: 1
# name: Klas Pontus Arnoldson, number of rows: 1
# name: Klaus Hasselmann, number of rows: 1
# name: Klaus von Klitzing, number of rows: 1
# name: Knut Hamsun, number of rows: 1
# name: Kofi Annan, number of rows: 1
# name: Koichi Tanaka, number of rows: 1
# name: Konrad Bloch, number of rows: 1
# name: Konrad Lorenz, number of rows: 1
# name: Konstantin Novoselov, number of rows: 1
# name: Kurt Alder, number of rows: 1
# name: Kurt Wüthrich, number of rows: 1
# name: Lars Onsager, number of rows: 2
# name: Lars Peter Hansen, number of rows: 1
# name: Lawrence R. Klein, number of rows: 1
# name: Lech Wałęsa, number of rows: 1
# name: Leland H. Hartwell, number of rows: 1
# name: Leo Esaki, number of rows: 1
# name: Leon M. Lederman, number of rows: 1
# name: Leon N. Cooper, number of rows: 1
# name: Leonid Hurwicz, number of rows: 1
# name: Leonid Kantorovich, number of rows: 1
# name: Lester B. Pearson, number of rows: 1
# name: Lev Landau, number of rows: 1
# name: Leymah Gbowee, number of rows: 1
# name: Linda B. Buck, number of rows: 1
# name: Linus C. Pauling, number of rows: 2
# name: Liu Xiaobo, number of rows: 1
# name: Lloyd S. Shapley, number of rows: 1
# name: Louis Brus, number of rows: 1
# name: Louis J. Ignarro, number of rows: 1
# name: Louis Néel, number of rows: 1
# name: Louis Renault, number of rows: 1
# name: Louis de Broglie, number of rows: 1
# name: Louise Glück, number of rows: 1
# name: Luc Montagnier, number of rows: 1
# name: Ludwig Quidde, number of rows: 1
# name: Luigi Pirandello, number of rows: 1
# name: Luis Alvarez, number of rows: 1
# name: Luis Federico Leloir, number of rows: 1
# name: Léon Bourgeois, number of rows: 1
# name: Léon Jouhaux, number of rows: 1
# name: Lê Đức Thọ, number of rows: 1
# name: M. Stanley Whittingham, number of rows: 2
# name: Mairead Corrigan, number of rows: 2
# name: Makoto Kobayashi, number of rows: 1
# name: Malala Yousafzai, number of rows: 1
# name: Manfred Eigen, number of rows: 1
# name: Maria Goeppert-Mayer, number of rows: 1
# name: Maria Ressa, number of rows: 2
# name: Marie Curie, number of rows: 2
# name: Marie Skłodowska-Curie, number of rows: 2
# name: Mario J. Molina, number of rows: 1
# name: Mario R. Capecchi, number of rows: 1
# name: Mario Vargas Llosa, number of rows: 1
# name: Marshall Warren Nirenberg, number of rows: 1
# name: Martin Chalfie, number of rows: 1
# name: Martin Karplus, number of rows: 1
# name: Martin L. Perl, number of rows: 1
# name: Martin Luther King Jr., number of rows: 1
# name: Martin Rodbell, number of rows: 1
# name: Martin Ryle, number of rows: 1
# name: Martinus J. G. Veltman, number of rows: 1
# name: Martti Ahtisaari, number of rows: 1
# name: Masatoshi Koshiba, number of rows: 1
# name: Maurice Allais, number of rows: 1
# name: Maurice Maeterlinck, number of rows: 1
# name: Maurice Wilkins, number of rows: 2
# name: Max Born, number of rows: 1
# name: Max Delbrück, number of rows: 1
# name: Max Karl Ernst Ludwig Planck, number of rows: 1
# name: Max Perutz, number of rows: 2
# name: Max Theiler, number of rows: 1
# name: Max von Laue, number of rows: 1
# name: May-Britt Moser, number of rows: 1
# name: Melvin Calvin, number of rows: 1
# name: Melvin Schwartz, number of rows: 1
# name: Memorial, number of rows: 1
# name: Menachem Begin, number of rows: 1
# name: Merton H. Miller, number of rows: 1
# name: Michael Houghton, number of rows: 1
# name: Michael Kremer, number of rows: 1
# name: Michael Levitt, number of rows: 3
# name: Michael Rosbash, number of rows: 1
# name: Michael S. Brown, number of rows: 1
# name: Michael Smith, number of rows: 1
# name: Michael W. Young, number of rows: 1
# name: Michel Mayor, number of rows: 1
# name: Miguel Ángel Asturias, number of rows: 1
# name: Mikhail Gorbachev, number of rows: 1
# name: Mikhail Sholokhov, number of rows: 1
# name: Milton Friedman, number of rows: 1
# name: Mo Yan, number of rows: 1
# name: Mohamed ElBaradei, number of rows: 1
# name: Morten P. Meldal, number of rows: 1
# name: Mother Teresa, number of rows: 1
# name: Moungi Bawendi, number of rows: 3
# name: Muhammad Yunus, number of rows: 1
# name: Murray Gell-Mann, number of rows: 1
# name: Myron Scholes, number of rows: 1
# name: Médecins Sans Frontières, number of rows: 1
# name: Nadia Murad, number of rows: 1
# name: Nadine Gordimer, number of rows: 1
# name: Naguib Mahfouz, number of rows: 1
# name: Narges Mohammadi, number of rows: 1
# name: Nathan Söderblom, number of rows: 1
# name: Nelly Sachs, number of rows: 1
# name: Nelson Mandela, number of rows: 1
# name: Nevill Francis Mott, number of rows: 1
# name: Nicholas M. Butler, number of rows: 1
# name: Nicolaas Bloembergen, number of rows: 1
# name: Niels Bohr, number of rows: 1
# name: Niels Kaj Jerne, number of rows: 1
# name: Niels Ryberg Finsen, number of rows: 1
# name: Nikolaas Tinbergen, number of rows: 1
# name: Nikolay Basov, number of rows: 1
# name: Nikolay Semyonov, number of rows: 1
# name: Norman Angell, number of rows: 1
# name: Norman Borlaug, number of rows: 1
# name: Norman F. Ramsey, number of rows: 1
# name: Norman Haworth, number of rows: 1
# name: Octavio Paz Lozano, number of rows: 1
# name: Odd Hassel, number of rows: 1
# name: Odysseas Elytis, number of rows: 1
# name: Olga Tokarczuk, number of rows: 1
# name: Oliver Eaton Williamson, number of rows: 1
# name: Oliver Hart, number of rows: 2
# name: Oliver Smithies, number of rows: 1
# name: Organisation for the Prohibition of Chemical Weapons, number of rows: 1
# name: Orhan Pamuk, number of rows: 1
# name: Osamu Shimomura, number of rows: 2
# name: Otto Diels, number of rows: 1
# name: Otto Fritz Meyerhof, number of rows: 1
# name: Otto Hahn, number of rows: 1
# name: Otto Heinrich Warburg, number of rows: 1
# name: Otto Loewi, number of rows: 1
# name: Otto Stern, number of rows: 1
# name: Otto Wallach, number of rows: 1
# name: Owen Chamberlain, number of rows: 1
# name: Owen Willans Richardson, number of rows: 1
# name: Pablo Neruda, number of rows: 1
# name: Patrick Blackett, number of rows: 1
# name: Patrick Modiano, number of rows: 1
# name: Patrick White, number of rows: 1
# name: Paul A. Samuelson, number of rows: 1
# name: Paul Berg, number of rows: 1
# name: Paul C. Lauterbur, number of rows: 1
# name: Paul D. Boyer, number of rows: 1
# name: Paul Dirac, number of rows: 1
# name: Paul Ehrlich, number of rows: 1
# name: Paul Greengard, number of rows: 1
# name: Paul Hermann Müller, number of rows: 1
# name: Paul J. Crutzen, number of rows: 2
# name: Paul J. Flory, number of rows: 1
# name: Paul Johann Ludwig Heyse, number of rows: 1
# name: Paul Karrer, number of rows: 1
# name: Paul Krugman, number of rows: 1
# name: Paul L. Modrich, number of rows: 1
# name: Paul Nurse, number of rows: 1
# name: Paul R. Milgrom, number of rows: 1
# name: Paul Romer, number of rows: 1
# name: Paul Sabatier, number of rows: 1
# name: Paul-Henri-Benjamin d'Estournelles de Constant, number of rows: 1
# name: Pavel Cherenkov, number of rows: 1
# name: Pearl S. Buck, number of rows: 1
# name: Percy W. Bridgman, number of rows: 1
# name: Peter A. Diamond, number of rows: 1
# name: Peter Agre, number of rows: 1
# name: Peter C. Doherty, number of rows: 1
# name: Peter D. Mitchell, number of rows: 1
# name: Peter Debye, number of rows: 1
# name: Peter Grünberg, number of rows: 1
# name: Peter Handke, number of rows: 1
# name: Peter Higgs, number of rows: 1
# name: Peter J. Ratcliffe, number of rows: 1
# name: Peter Mansfield, number of rows: 1
# name: Peter Medawar, number of rows: 1
# name: Philip Anderson, number of rows: 1
# name: Philip H. Dybvig, number of rows: 1
# name: Philip Noel-Baker, number of rows: 1
# name: Philip S. Hench, number of rows: 1
# name: Philipp Lenard, number of rows: 1
# name: Phillip A. Sharp, number of rows: 1
# name: Pierre Agostini, number of rows: 1
# name: Pierre Curie, number of rows: 1
# name: Pierre-Gilles de Gennes, number of rows: 1
# name: Pieter Zeeman, number of rows: 1
# name: Polykarp Kusch, number of rows: 1
# name: Pugwash Conferences on Science and World Affairs, number of rows: 1
# name: Pyotr Kapitsa, number of rows: 1
# name: Pär Lagerkvist, number of rows: 1
# name: Rabindranath Tagore  ', number of rows: 1
# name: Ragnar Frisch, number of rows: 1
# name: Ragnar Granit, number of rows: 2
# name: Rainer Weiss, number of rows: 1
# name: Ralph J. Bunche, number of rows: 1
# name: Ralph M. Steinman, number of rows: 2
# name: Randy Schekman, number of rows: 1
# name: Raymond Davis Jr., number of rows: 1
# name: Reinhard Genzel, number of rows: 1
# name: Reinhard Selten, number of rows: 1
# name: Renato Dulbecco, number of rows: 1
# name: René Cassin, number of rows: 1
# name: Riccardo Giacconi, number of rows: 1
# name: Richard Axel, number of rows: 1
# name: Richard E. Smalley, number of rows: 1
# name: Richard E. Taylor, number of rows: 1
# name: Richard F. Heck, number of rows: 1
# name: Richard H. Thaler, number of rows: 1
# name: Richard Henderson, number of rows: 1
# name: Richard J. Roberts, number of rows: 1
# name: Richard Kuhn, number of rows: 1
# name: Richard Laurence Millington Synge, number of rows: 1
# name: Richard P. Feynman, number of rows: 1
# name: Richard R. Ernst, number of rows: 1
# name: Richard R. Schrock, number of rows: 1
# name: Richard Stone, number of rows: 1
# name: Richard Willstätter, number of rows: 1
# name: Richárd Zsigmondy, number of rows: 1
# name: Rigoberta Menchú, number of rows: 1
# name: Rita Levi-Montalcini, number of rows: 2
# name: Roald Hoffmann, number of rows: 1
# name: Robert A. Millikan, number of rows: 1
# name: Robert Aumann, number of rows: 1
# name: Robert B. Laughlin, number of rows: 1
# name: Robert B. Wilson, number of rows: 1
# name: Robert B. Woodward, number of rows: 1
# name: Robert C. Merton, number of rows: 1
# name: Robert C. Richardson, number of rows: 1
# name: Robert Cecil, number of rows: 1
# name: Robert F. Curl Jr., number of rows: 1
# name: Robert F. Engle, number of rows: 1
# name: Robert F. Furchgott, number of rows: 1
# name: Robert G. Edwards, number of rows: 1
# name: Robert H. Grubbs, number of rows: 1
# name: Robert Hofstadter, number of rows: 1
# name: Robert Huber, number of rows: 1
# name: Robert J. Lefkowitz, number of rows: 1
# name: Robert J. Shiller, number of rows: 1
# name: Robert Koch, number of rows: 1
# name: Robert Lucas Jr., number of rows: 1
# name: Robert M. Solow, number of rows: 1
# name: Robert Mundell, number of rows: 1
# name: Robert Robinson, number of rows: 1
# name: Robert S. Mulliken, number of rows: 1
# name: Robert Schrieffer, number of rows: 1
# name: Robert W. Fogel, number of rows: 1
# name: Robert W. Holley, number of rows: 1
# name: Robert Woodrow Wilson, number of rows: 1
# name: Roderick MacKinnon, number of rows: 1
# name: Rodney Robert Porter, number of rows: 1
# name: Roger B. Myerson, number of rows: 1
# name: Roger D. Kornberg, number of rows: 1
# name: Roger Guillemin, number of rows: 1
# name: Roger Martin du Gard, number of rows: 1
# name: Roger Penrose, number of rows: 1
# name: Roger W. Sperry, number of rows: 1
# name: Roger Yonchien Tsien, number of rows: 1
# name: Rolf M. Zinkernagel, number of rows: 1
# name: Rolf Zinkernagel, number of rows: 1
# name: Romain Rolland, number of rows: 1
# name: Ronald Coase, number of rows: 2
# name: Ronald George Wreyford Norrish, number of rows: 1
# name: Ronald Ross, number of rows: 1
# name: Rosalyn Yalow, number of rows: 1
# name: Roy J. Glauber, number of rows: 1
# name: Rudolf Christoph Eucken, number of rows: 1
# name: Rudolf Mössbauer, number of rows: 1
# name: Rudolph A. Marcus, number of rows: 1
# name: Rudyard Kipling, number of rows: 1
# name: Russell A. Hulse, number of rows: 1
# name: Ryōji Noyori, number of rows: 1
# name: Róbert Bárány, number of rows: 1
# name: Saint-John Perse, number of rows: 1
# name: Salvador Luria, number of rows: 1
# name: Salvatore Quasimodo, number of rows: 1
# name: Samuel Beckett, number of rows: 1
# name: Samuel C. C. Ting, number of rows: 2
# name: Santiago Ramón y Cajal, number of rows: 1
# name: Satoshi Ōmura, number of rows: 1
# name: Saul Bellow, number of rows: 1
# name: Saul Perlmutter, number of rows: 1
# name: Selma Lagerlöf, number of rows: 1
# name: Selman A. Waksman, number of rows: 1
# name: Serge Haroche, number of rows: 1
# name: Severo Ochoa, number of rows: 1
# name: Seán MacBride, number of rows: 1
# name: Sheldon Glashow, number of rows: 1
# name: Shimon Peres, number of rows: 1
# name: Shinya Yamanaka, number of rows: 1
# name: Shirin Ebadi, number of rows: 1
# name: Shmuel Yosef Agnon, number of rows: 1
# name: Shuji Nakamura, number of rows: 1
# name: Sidney Altman, number of rows: 1
# name: Sigrid Undset, number of rows: 1
# name: Simon Kuznets, number of rows: 2
# name: Simon van der Meer, number of rows: 1
# name: Sin-Itiro Tomonaga, number of rows: 1
# name: Sinclair Lewis, number of rows: 1
# name: Sir Frank Macfarlane Burnet, number of rows: 1
# name: Sir Martin J. Evans, number of rows: 1
# name: Stanford Moore, number of rows: 1
# name: Stanley B. Prusiner, number of rows: 1
# name: Stanley Cohen, number of rows: 1
# name: Stefan Hell, number of rows: 1
# name: Steven Chu, number of rows: 1
# name: Steven Weinberg, number of rows: 1
# name: Subrahmanyan Chandrasekhar, number of rows: 1
# name: Sully Prudhomme, number of rows: 1
# name: Sune Bergström, number of rows: 1
# name: Susumu Tonegawa, number of rows: 1
# name: Svante Arrhenius, number of rows: 1
# name: Svante Pääbo, number of rows: 2
# name: Svetlana Alexievich, number of rows: 1
# name: Sydney Brenner, number of rows: 2
# name: Syukuro Manabe, number of rows: 1
# name: Séamus Heaney, number of rows: 1
# name: T. S. Eliot, number of rows: 1
# name: Tadeusz Reichstein, number of rows: 1
# name: Takaaki Kajita, number of rows: 1
# name: Tasuku Honjo, number of rows: 1
# name: Tawakkol Karman, number of rows: 1
# name: Theodor Kocher, number of rows: 1
# name: Theodor Mommsen, number of rows: 1
# name: Theodor Svedberg, number of rows: 1
# name: Theodor W. Hänsch, number of rows: 1
# name: Theodore Roosevelt, number of rows: 1
# name: Theodore Schultz, number of rows: 1
# name: Theodore W. Richards, number of rows: 1
# name: Thomas A. Steitz, number of rows: 1
# name: Thomas C. Südhof, number of rows: 2
# name: Thomas H. Morgan, number of rows: 1
# name: Thomas H. Weller, number of rows: 1
# name: Thomas J. Sargent, number of rows: 1
# name: Thomas Mann, number of rows: 1
# name: Thomas R. Cech, number of rows: 1
# name: Thomas Schelling, number of rows: 1
# name: Tim Hunt, number of rows: 1
# name: Tjalling C. Koopmans, number of rows: 2
# name: Tobias Asser, number of rows: 1
# name: Tomas Lindahl, number of rows: 2
# name: Tomas Tranströmer, number of rows: 1
# name: Toni Morrison, number of rows: 1
# name: Torsten Wiesel, number of rows: 1
# name: Toshihide Maskawa, number of rows: 1
# name: Trygve Haavelmo, number of rows: 1
# name: Tsung-Dao Lee, number of rows: 1
# name: Tu Youyou, number of rows: 1
# name: Ulf von Euler, number of rows: 1
# name: V. S. Naipaul, number of rows: 1
# name: Val Fitch, number of rows: 1
# name: Venkatraman Ramakrishnan, number of rows: 2
# name: Vernon L. Smith, number of rows: 1
# name: Vicente Aleixandre, number of rows: 1
# name: Victor Francis Hess, number of rows: 1
# name: Victor Grignard, number of rows: 1
# name: Vincent du Vigneaud, number of rows: 1
# name: Vitaly Ginzburg, number of rows: 1
# name: W. Arthur Lewis, number of rows: 1
# name: W. B. Yeats, number of rows: 1
# name: Walter Gilbert, number of rows: 1
# name: Walter H. Brattain, number of rows: 1
# name: Walter Kohn, number of rows: 1
# name: Walter Rudolf Hess, number of rows: 1
# name: Walther Bothe, number of rows: 1
# name: Walther Nernst, number of rows: 1
# name: Wangari Maathai, number of rows: 1
# name: Wassily Leontief, number of rows: 1
# name: Wendell M. Stanley, number of rows: 1
# name: Werner Arber, number of rows: 1
# name: Werner Forssmann, number of rows: 1
# name: Werner Karl Heisenberg, number of rows: 1
# name: Wilhelm Conrad Röntgen, number of rows: 1
# name: Wilhelm Ostwald, number of rows: 1
# name: Wilhelm Wien, number of rows: 1
# name: Willard F. Libby, number of rows: 1
# name: Willard S. Boyle, number of rows: 1
# name: Willem Einthoven, number of rows: 1
# name: William A. Fowler, number of rows: 1
# name: William B. Shockley, number of rows: 1
# name: William C. Campbell, number of rows: 2
# name: William D. Phillips, number of rows: 1
# name: William E. Moerner, number of rows: 1
# name: William F. Sharpe, number of rows: 1
# name: William Faulkner, number of rows: 1
# name: William Giauque, number of rows: 1
# name: William Golding, number of rows: 1
# name: William H. Stein, number of rows: 1
# name: William Henry Bragg, number of rows: 2
# name: William Kaelin Jr., number of rows: 1
# name: William Lawrence Bragg, number of rows: 2
# name: William Lipscomb, number of rows: 1
# name: William Nordhaus, number of rows: 1
# name: William P. Murphy, number of rows: 1
# name: William Ramsay, number of rows: 1
# name: William Randal Cremer, number of rows: 1
# name: William S. Knowles, number of rows: 1
# name: William Vickrey, number of rows: 1
# name: Willis E. Lamb, number of rows: 1
# name: Willy Brandt, number of rows: 1
# name: Winston Churchill, number of rows: 1
# name: Wisława Szymborska, number of rows: 1
# name: Wole Soyinka, number of rows: 1
# name: Wolfgang Ketterle, number of rows: 1
# name: Wolfgang Paul, number of rows: 1
# name: Wolfgang Pauli, number of rows: 1
# name: Woodrow Wilson, number of rows: 1
# name: Władysław Reymont, number of rows: 1
# name: Yasser Arafat, number of rows: 1
# name: Yasunari Kawabata, number of rows: 1
# name: Yitzhak Rabin, number of rows: 1
# name: Yoichiro Nambu, number of rows: 1
# name: Yoshinori Ohsumi, number of rows: 1
# name: Yuan T. Lee, number of rows: 2
# name: Yves Chauvin, number of rows: 1
# name: Zhores Alferov, number of rows: 1
# name: Élie Ducommun, number of rows: 1
# name: Élie Metchnikoff, number of rows: 1
# name: Óscar Arias Sánchez, number of rows: 1

# %%
pd.concat([g for _, g in df.groupby("name") if len(g) > 1])["name"]
# Out:
# 275           Alan MacDiarmid
# 767           Alan MacDiarmid
# 598           Albert Einstein
# 913           Albert Einstein
# 432             Alexei Ekimov
#                 ...
# 444       William Henry Bragg
# 0      William Lawrence Bragg
# 460    William Lawrence Bragg
# 207               Yuan T. Lee
# 582               Yuan T. Lee
# Name: name, Length: 136, dtype: object

# %%
# sorting data
df2 = pd.DataFrame(
    {"name": ["zak", "alice", "bob", "mike", "bob", "bob"], "score": [4, 3, 5, 2, 3, 7]}
)
df2.sort_values(["name", "score"], ascending=[1, 0])
# Out:
#     name  score
# 1  alice      3
# 5    bob      7
# 2    bob      5
# 4    bob      3
# 3   mike      2
# 0    zak      4

# %%
all_dupes.sort_values('name')[['name','country','year']]
# Out:
#                        name         country  year
# 767         Alan MacDiarmid     New Zealand  2000
# 275         Alan MacDiarmid   United States  2000
# 598         Albert Einstein     Switzerland  1921
# 913         Albert Einstein         Germany  1921
# 432           Alexei Ekimov   United States  2023
# ..                      ...             ...   ...
# 73      William Henry Bragg       Australia  1915
# 460  William Lawrence Bragg  United Kingdom  1915
# 0    William Lawrence Bragg       Australia  1915
# 582             Yuan T. Lee          Taiwan  1986
# 207             Yuan T. Lee   United States  1986
#
# [136 rows x 3 columns]

# %%
df.drop(df[(df.name == 'Sidney Altman') & (df.year == 1990)].index,inplace=True)

# %%
df = df[~((df.name == "Sidney Altman") & (df.year == 1990))]

# %%
def cleane_data(df):
    df = df.replace("", np.nan)
    df = df[df.born_in_isnull()]
    df = df.drop("born_in", axis=1)
    df.drop(df[df.year == 1809].index, inplace=True)
    df = df[~(df.name == "Marie Curie")]
    df.loc[
        (df.name == "Marie Sk\u0142odowska-Curie") & (df.year == 1911), "country"
    ] = "France"
    df = df[~((df.name == "Sidney Altman") & (df.year == 1990))]
    return df

df = df.reindex(np.random.permutation(df.index))
df = df.drop_duplicates(['name','year'])
df = df.sort_index()
df.count()
# Out:
# link              994
# name              994
# year              994
# category          993
# country           994
# text              994
# date_of_birth     985
# date_of_death     685
# place_of_birth    985
# place_of_death    682
# gender            985
# dtype: int64

# %%
df[df.duplicated('name')|df.duplicated('name',keep='last')].sort_values(by='name')[['name','country','year','category']]
# Out:
#                         name         country  year                category
# 480         Frederick Sanger  United Kingdom  1958               Chemistry
# 510         Frederick Sanger  United Kingdom  1980               Chemistry
# 79              John Bardeen   United States  1956                 Physics
# 134             John Bardeen   United States  1972                 Physics
# 292       K. Barry Sharpless   United States  2001               Chemistry
# 424       K. Barry Sharpless   United States  2022               Chemistry
# 77          Linus C. Pauling   United States  1954               Chemistry
# 104         Linus C. Pauling   United States  1962                   Peace
# 1010             Marie Curie          France  1903                 Physics
# 1016             Marie Curie          France  1911               Chemistry
# 708   Marie Skłodowska-Curie          Poland  1911               Chemistry
# 716   Marie Skłodowska-Curie          Poland  1903                 Physics
# 623            Ragnar Granit          Sweden  1967  Physiology or Medicine
# 1081           Ragnar Granit         Finland  1809  Physiology or Medicine

# %%
df[df.category.isnull()][['name', 'text']]
# Out:
#               name                                               text
# 875  Róbert Bárány  Róbert Bárány ,  born in Austria , Medicine, 1914

# %%
df.loc[df.name =='Róbert Bárány','category'] = 'Physiology or Medicine'

# %%
df[df.gender.isnull()]['name']
# Out:
# 66      American Friends Service Committee  (The Quakers)
# 472                               Friends Service Council
# 504                                 Amnesty International
# 590                            Centre for Civil Liberties
# 695                                              Memorial
# 769     Organisation for the Prohibition of Chemical W...
# 1060                             Médecins Sans Frontières
# 1162                      Institut de Droit International
# 1170     Pugwash Conferences on Science and World Affairs
# Name: name, dtype: object

# %%
def cleane_data(df):
    df = df.replace("", np.nan)
    # df = df[df.born_in.isnull()]
    # df = df.drop("born_in", axis=1)
    df.drop(df[df.year == 1809].index, inplace=True)
    df = df[~(df.name == "Marie Curie")]
    df.loc[
        (df.name == "Marie Sk\u0142odowska-Curie") & (df.year == 1911), "country"
    ] = "France"
    df = df[~((df.name == "Sidney Altman") & (df.year == 1990))]
    df.loc[df.name == "Ragnar Granit", "gender"] = "male"
    df = df[df.gender.notnull()]
    return df

# %%
df = cleane_data(df)
df.count()
# Out:
# link              980
# name              980
# year              980
# category          980
# country           980
# text              980
# date_of_birth     980
# date_of_death     680
# place_of_birth    980
# place_of_death    677
# gender            980
# dtype: int64

# %%
df[df.date_of_birth.isnull()]['name']
# Out:
# Series([], Name: name, dtype: object)

# %%
# dealign with time and dates
df[['name','date_of_birth']]
# Out:
#                         name      date_of_birth
# 0     William Lawrence Bragg      31 March 1890
# 1              Brian Schmidt   24 February 1967
# 3             Barry Marshall  30 September 1951
# 4            J. Robin Warren       11 June 1937
# 5           Peter C. Doherty    15 October 1940
# ...                      ...                ...
# 1196           Konrad Lorenz    7 November 1903
# 1199     Carl Ferdinand Cori    5 December 1896
# 1200         Anton Zeilinger        20 May 1945
# 1201            Peter Handke    6 December 1942
# 1203        Elfriede Jelinek    20 October 1946
#
# [980 rows x 2 columns]

# %%
pd.to_datetime(df.date_of_birth,errors='raise')
# Out:
# 0      1890-03-31
# 1      1967-02-24
# 3      1951-09-30
# 4      1937-06-11
# 5      1940-10-15
#           ...
# 1196   1903-11-07
# 1199   1896-12-05
# 1200   1945-05-20
# 1201   1942-12-06
# 1203   1946-10-20
# Name: date_of_birth, Length: 980, dtype: datetime64[ns]

# %%
df.date_of_birth = pd.to_datetime(df.date_of_birth,errors='coerce')
df.head()
# Out:
#                                                 link                    name  \
# 0  http://en.wikipedia.org/wiki/William_Lawrence_...  William Lawrence Bragg
# 1         http://en.wikipedia.org/wiki/Brian_Schmidt           Brian Schmidt
# 3        http://en.wikipedia.org/wiki/Barry_Marshall          Barry Marshall
# 4          http://en.wikipedia.org/wiki/Robin_Warren         J. Robin Warren
# 5      http://en.wikipedia.org/wiki/Peter_C._Doherty        Peter C. Doherty
#
#    year                category    country  \
# 0  1915                 Physics  Australia
# 1  2011                 Physics  Australia
# 3  2005  Physiology or Medicine  Australia
# 4  2005  Physiology or Medicine  Australia
# 5  1996  Physiology or Medicine  Australia
#
#                                                 text date_of_birth  \
# 0             William Lawrence Bragg , Physics, 1915    1890-03-31
# 1  Brian Schmidt ,  born in the United States , P...    1967-02-24
# 3      Barry Marshall , Physiology or Medicine, 2005    1951-09-30
# 4     J. Robin Warren , Physiology or Medicine, 2005    1937-06-11
# 5    Peter C. Doherty , Physiology or Medicine, 1996    1940-10-15
#
#   date_of_death place_of_birth place_of_death gender
# 0   1 July 1971       Adelaide        Ipswich   male
# 1           NaN       Missoula            NaN   male
# 3           NaN     Kalgoorlie            NaN   male
# 4           NaN       Adelaide            NaN   male
# 5           NaN       Brisbane            NaN   male

# %%
pd.to_datetime(df.date_of_death, errors='raise')
# Out:
# 0      1971-07-01
# 1             NaT
# 3             NaT
# 4             NaT
# 5             NaT
#           ...
# 1196   1989-02-27
# 1199   1984-10-20
# 1200          NaT
# 1201          NaT
# 1203          NaT
# Name: date_of_death, Length: 980, dtype: datetime64[ns]

# %%
for i,row in df.iterrows():
    try:
        pd.to_datetime(row.date_of_death, errors='raise')
    except:
        print(f"{row.date_of_death.ljust(30)}({row['name']}, {i})")

# %%
# gets all rows with non-null date fields
with_death_dates = df[df.date_of_death.notnull()]
with_death_dates.head()
# Out:
#                                                  link                    name  \
# 0   http://en.wikipedia.org/wiki/William_Lawrence_...  William Lawrence Bragg
# 10  http://en.wikipedia.org/wiki/Luis_Federico_Leloir    Luis Federico Leloir
# 11       http://en.wikipedia.org/wiki/Ivo_Andri%C4%87              Ivo Andrić
# 12      http://en.wikipedia.org/wiki/Bernardo_Houssay        Bernardo Houssay
# 13  http://en.wikipedia.org/wiki/Carlos_Saavedra_L...   Carlos Saavedra Lamas
#
#     year                category     country  \
# 0   1915                 Physics   Australia
# 10  1970               Chemistry   Argentina
# 11  1961              Literature  Yugoslavia
# 12  1947  Physiology or Medicine   Argentina
# 13  1936                   Peace   Argentina
#
#                                                  text date_of_birth  \
# 0              William Lawrence Bragg , Physics, 1915    1890-03-31
# 10  Luis Federico Leloir ,  born in France , Chemi...    1906-09-06
# 11  Ivo Andrić ,  born in the  Condominium of Bosn...    1892-10-09
# 12    Bernardo Houssay , Physiology or Medicine, 1947    1887-04-10
# 13                Carlos Saavedra Lamas , Peace, 1936    1878-11-01
#
#         date_of_death place_of_birth      place_of_death gender
# 0         1 July 1971       Adelaide             Ipswich   male
# 10    2 December 1987          Paris  Catamarca Province   male
# 11      13 March 1975          Dolac            Belgrade   male
# 12  21 September 1971   Buenos Aires        Buenos Aires   male
# 13         5 May 1959   Buenos Aires        Buenos Aires   male

# %%
bad_dates = pd.isnull(pd.to_datetime(with_death_dates.date_of_death, errors="coerce"))
bad_dates.head()
# Out:
# 0     False
# 10    False
# 11    False
# 12    False
# 13    False
# Name: date_of_death, dtype: bool

# %%
with_death_dates[bad_dates][["category", "date_of_death", "name"]]
# Out:
# Empty DataFrame
# Columns: [category, date_of_death, name]
# Index: []

# %%
df.date_of_death = pd.to_datetime(df.date_of_death, errors="coerce")
df
# Out:
#                                                    link  \
# 0     http://en.wikipedia.org/wiki/William_Lawrence_...
# 1            http://en.wikipedia.org/wiki/Brian_Schmidt
# 3           http://en.wikipedia.org/wiki/Barry_Marshall
# 4             http://en.wikipedia.org/wiki/Robin_Warren
# 5         http://en.wikipedia.org/wiki/Peter_C._Doherty
# ...                                                 ...
# 1196         http://en.wikipedia.org/wiki/Konrad_Lorenz
# 1199   http://en.wikipedia.org/wiki/Carl_Ferdinand_Cori
# 1200       http://en.wikipedia.org/wiki/Anton_Zeilinger
# 1201          http://en.wikipedia.org/wiki/Peter_Handke
# 1203      http://en.wikipedia.org/wiki/Elfriede_Jelinek
#
#                         name  year                category    country  \
# 0     William Lawrence Bragg  1915                 Physics  Australia
# 1              Brian Schmidt  2011                 Physics  Australia
# 3             Barry Marshall  2005  Physiology or Medicine  Australia
# 4            J. Robin Warren  2005  Physiology or Medicine  Australia
# 5           Peter C. Doherty  1996  Physiology or Medicine  Australia
# ...                      ...   ...                     ...        ...
# 1196           Konrad Lorenz  1973  Physiology or Medicine    Austria
# 1199     Carl Ferdinand Cori  1947  Physiology or Medicine    Austria
# 1200         Anton Zeilinger  2022                 Physics    Austria
# 1201            Peter Handke  2019              Literature    Austria
# 1203        Elfriede Jelinek  2004              Literature    Austria
#
#                                                    text date_of_birth  \
# 0                William Lawrence Bragg , Physics, 1915    1890-03-31
# 1     Brian Schmidt ,  born in the United States , P...    1967-02-24
# 3         Barry Marshall , Physiology or Medicine, 2005    1951-09-30
# 4        J. Robin Warren , Physiology or Medicine, 2005    1937-06-11
# 5       Peter C. Doherty , Physiology or Medicine, 1996    1940-10-15
# ...                                                 ...           ...
# 1196       Konrad Lorenz , Physiology or Medicine, 1973    1903-11-07
# 1199  Carl Ferdinand Cori ,  born in Austria , Physi...    1896-12-05
# 1200                    Anton Zeilinger , Physics, 2022    1945-05-20
# 1201                    Peter Handke , Literature, 2019    1942-12-06
# 1203                Elfriede Jelinek , Literature, 2004    1946-10-20
#
#      date_of_death    place_of_birth place_of_death  gender
# 0       1971-07-01          Adelaide        Ipswich    male
# 1              NaT          Missoula            NaN    male
# 3              NaT        Kalgoorlie            NaN    male
# 4              NaT          Adelaide            NaN    male
# 5              NaT          Brisbane            NaN    male
# ...            ...               ...            ...     ...
# 1196    1989-02-27            Vienna         Vienna    male
# 1199    1984-10-20            Prague      Cambridge    male
# 1200           NaT  Ried im Innkreis            NaN    male
# 1201           NaT           Griffen            NaN    male
# 1203           NaT      Mürzzuschlag            NaN  female
#
# [980 rows x 11 columns]

# %%
# hwo old were they when they got their award
df['award_age'] = df.year - pd.DatetimeIndex(df.date_of_birth).year

# %%
df
# Out:
#                                                    link  \
# 0     http://en.wikipedia.org/wiki/William_Lawrence_...
# 1            http://en.wikipedia.org/wiki/Brian_Schmidt
# 3           http://en.wikipedia.org/wiki/Barry_Marshall
# 4             http://en.wikipedia.org/wiki/Robin_Warren
# 5         http://en.wikipedia.org/wiki/Peter_C._Doherty
# ...                                                 ...
# 1196         http://en.wikipedia.org/wiki/Konrad_Lorenz
# 1199   http://en.wikipedia.org/wiki/Carl_Ferdinand_Cori
# 1200       http://en.wikipedia.org/wiki/Anton_Zeilinger
# 1201          http://en.wikipedia.org/wiki/Peter_Handke
# 1203      http://en.wikipedia.org/wiki/Elfriede_Jelinek
#
#                         name  year                category    country  \
# 0     William Lawrence Bragg  1915                 Physics  Australia
# 1              Brian Schmidt  2011                 Physics  Australia
# 3             Barry Marshall  2005  Physiology or Medicine  Australia
# 4            J. Robin Warren  2005  Physiology or Medicine  Australia
# 5           Peter C. Doherty  1996  Physiology or Medicine  Australia
# ...                      ...   ...                     ...        ...
# 1196           Konrad Lorenz  1973  Physiology or Medicine    Austria
# 1199     Carl Ferdinand Cori  1947  Physiology or Medicine    Austria
# 1200         Anton Zeilinger  2022                 Physics    Austria
# 1201            Peter Handke  2019              Literature    Austria
# 1203        Elfriede Jelinek  2004              Literature    Austria
#
#                                                    text date_of_birth  \
# 0                William Lawrence Bragg , Physics, 1915    1890-03-31
# 1     Brian Schmidt ,  born in the United States , P...    1967-02-24
# 3         Barry Marshall , Physiology or Medicine, 2005    1951-09-30
# 4        J. Robin Warren , Physiology or Medicine, 2005    1937-06-11
# 5       Peter C. Doherty , Physiology or Medicine, 1996    1940-10-15
# ...                                                 ...           ...
# 1196       Konrad Lorenz , Physiology or Medicine, 1973    1903-11-07
# 1199  Carl Ferdinand Cori ,  born in Austria , Physi...    1896-12-05
# 1200                    Anton Zeilinger , Physics, 2022    1945-05-20
# 1201                    Peter Handke , Literature, 2019    1942-12-06
# 1203                Elfriede Jelinek , Literature, 2004    1946-10-20
#
#      date_of_death    place_of_birth place_of_death  gender  award_age
# 0       1971-07-01          Adelaide        Ipswich    male         25
# 1              NaT          Missoula            NaN    male         44
# 3              NaT        Kalgoorlie            NaN    male         54
# 4              NaT          Adelaide            NaN    male         68
# 5              NaT          Brisbane            NaN    male         56
# ...            ...               ...            ...     ...        ...
# 1196    1989-02-27            Vienna         Vienna    male         70
# 1199    1984-10-20            Prague      Cambridge    male         51
# 1200           NaT  Ried im Innkreis            NaN    male         77
# 1201           NaT           Griffen            NaN    male         77
# 1203           NaT      Mürzzuschlag            NaN  female         58
#
# [980 rows x 12 columns]

# %%
df.sort_values("award_age").iloc[:10][["name", "award_age", "category", "year"]]
# Out:
#                        name  award_age category  year
# 745        Malala Yousafzai         17    Peace  2014
# 0    William Lawrence Bragg         25  Physics  1915
# 858             Nadia Murad         25    Peace  2018
# 46            Carl Anderson         31  Physics  1936
# 448              Paul Dirac         31  Physics  1933
# 946  Werner Karl Heisenberg         31  Physics  1932
# 92            Tsung-Dao Lee         31  Physics  1957
# 863        Mairead Corrigan         32    Peace  1976
# 960        Rudolf Mössbauer         32  Physics  1961
# 23          Tawakkol Karman         32    Peace  2011

# %%
def clean_data(df):
    df = df.replace("", np.nan)
    df_born_in = df[df.born_in.notnull()]
    df = df[df.born_in.isnull()]
    df = df.drop("born_in", axis=1)
    df.drop(df[df.year == 1809].index, inplace=True)
    df = df[~(df.name == "Marie Curie")]
    df.loc[
        (df.name == "Marie Sk\u0142odowska-Curie") & (df.year == 1911), "country"
    ] = "France"
    df = df[~((df.name == "Sidney Altman") & (df.year == 1990))]
    df = df.reindex(np.random.permutation(df.index))
    df = df.drop_duplicates(["name", "year"])
    df = df.sort_index()
    df.loc[df.name == "Alexis Carrel", "category"] = "Physiology or Medicine"
    df.loc[df.name == "Ragnar Granit", "gender"] = "male"
    df = df[df.gender.notnull()]  # remove institutional prizes
    df.loc[df.name == "Hiroshi Amano", "date_of_birth"] = "11 September 1960"
    df.date_of_birth = pd.to_datetime(df.date_of_birth)
    df.date_of_death = pd.to_datetime(df.date_of_death, errors="coerce")
    df["award_age"] = df.year - pd.DatetimeIndex(df.date_of_birth).year

    return df, df_born_in

# %%
df = pd.read_json(open("data/nobel_winners.json"))
df_clean, df_born_in = clean_data(df)
df_clean
# Out:
#                                                    link  \
# 0     http://en.wikipedia.org/wiki/William_Lawrence_...
# 1            http://en.wikipedia.org/wiki/Brian_Schmidt
# 3           http://en.wikipedia.org/wiki/Barry_Marshall
# 4             http://en.wikipedia.org/wiki/Robin_Warren
# 5         http://en.wikipedia.org/wiki/Peter_C._Doherty
# ...                                                 ...
# 1195       http://en.wikipedia.org/wiki/Friedrich_Hayek
# 1196         http://en.wikipedia.org/wiki/Konrad_Lorenz
# 1200       http://en.wikipedia.org/wiki/Anton_Zeilinger
# 1201          http://en.wikipedia.org/wiki/Peter_Handke
# 1203      http://en.wikipedia.org/wiki/Elfriede_Jelinek
#
#                         name  year                category    country  \
# 0     William Lawrence Bragg  1915                 Physics  Australia
# 1              Brian Schmidt  2011                 Physics  Australia
# 3             Barry Marshall  2005  Physiology or Medicine  Australia
# 4            J. Robin Warren  2005  Physiology or Medicine  Australia
# 5           Peter C. Doherty  1996  Physiology or Medicine  Australia
# ...                      ...   ...                     ...        ...
# 1195         Friedrich Hayek  1974               Economics    Austria
# 1196           Konrad Lorenz  1973  Physiology or Medicine    Austria
# 1200         Anton Zeilinger  2022                 Physics    Austria
# 1201            Peter Handke  2019              Literature    Austria
# 1203        Elfriede Jelinek  2004              Literature    Austria
#
#                                                    text date_of_birth  \
# 0                William Lawrence Bragg , Physics, 1915    1890-03-31
# 1     Brian Schmidt ,  born in the United States , P...    1967-02-24
# 3         Barry Marshall , Physiology or Medicine, 2005    1951-09-30
# 4        J. Robin Warren , Physiology or Medicine, 2005    1937-06-11
# 5       Peter C. Doherty , Physiology or Medicine, 1996    1940-10-15
# ...                                                 ...           ...
# 1195                  Friedrich Hayek , Economics, 1974    1899-05-08
# 1196       Konrad Lorenz , Physiology or Medicine, 1973    1903-11-07
# 1200                    Anton Zeilinger , Physics, 2022    1945-05-20
# 1201                    Peter Handke , Literature, 2019    1942-12-06
# 1203                Elfriede Jelinek , Literature, 2004    1946-10-20
#
#      date_of_death    place_of_birth        place_of_death  gender  award_age
# 0       1971-07-01          Adelaide               Ipswich    male         25
# 1              NaT          Missoula                   NaN    male         44
# 3              NaT        Kalgoorlie                   NaN    male         54
# 4              NaT          Adelaide                   NaN    male         68
# 5              NaT          Brisbane                   NaN    male         56
# ...            ...               ...                   ...     ...        ...
# 1195    1992-03-23            Vienna  Freiburg im Breisgau    male         75
# 1196    1989-02-27            Vienna                Vienna    male         70
# 1200           NaT  Ried im Innkreis                   NaN    male         77
# 1201           NaT           Griffen                   NaN    male         77
# 1203           NaT      Mürzzuschlag                   NaN  female         58
#
# [980 rows x 12 columns]

# %%
df_born_in.name
# Out:
# 2       Elizabeth Blackburn *
# 7            John Cornforth *
# 8            César Milstein *
# 20         Baruj Benacerraf *
# 65              T. S. Eliot *
#                 ...
# 1191           Richard Kuhn *
# 1197        Karl von Frisch *
# 1202         Martin Karplus *
# 1204            Eric Kandel *
# 1205            Walter Kohn *
# Name: name, Length: 149, dtype: object

# %%
# remove * form the names
df_born_in.name = df_born_in.name.str.replace('*', '', regex=False)
# remove white space
df_born_in.name = df_born_in.name.str.strip()
# remove duplicate names
df_born_in.drop_duplicates(subset=['name'], inplace=True)
# set index to name
df_born_in.set_index('name', inplace=True)
df_born_in
# Out:
#                                                                  link  year  \
# name
# Elizabeth Blackburn  http://en.wikipedia.org/wiki/Elizabeth_Blackburn  2009
# John Cornforth            http://en.wikipedia.org/wiki/John_Cornforth  1975
# César Milstein       http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein  1984
# Baruj Benacerraf        http://en.wikipedia.org/wiki/Baruj_Benacerraf  1980
# T. S. Eliot                  http://en.wikipedia.org/wiki/T._S._Eliot  1948
# ...                                                               ...   ...
# Richard Kuhn                http://en.wikipedia.org/wiki/Richard_Kuhn  1938
# Karl von Frisch          http://en.wikipedia.org/wiki/Karl_von_Frisch  1973
# Martin Karplus            http://en.wikipedia.org/wiki/Martin_Karplus  2013
# Eric Kandel                  http://en.wikipedia.org/wiki/Eric_Kandel  2000
# Walter Kohn                  http://en.wikipedia.org/wiki/Walter_Kohn  1998
#
#                                    category country        born_in  \
# name
# Elizabeth Blackburn  Physiology or Medicine     NaN      Australia
# John Cornforth                    Chemistry     NaN      Australia
# César Milstein       Physiology or Medicine     NaN      Argentina
# Baruj Benacerraf     Physiology or Medicine     NaN      Venezuela
# T. S. Eliot                      Literature     NaN  United States
# ...                                     ...     ...            ...
# Richard Kuhn                      Chemistry     NaN        Austria
# Karl von Frisch      Physiology or Medicine     NaN        Austria
# Martin Karplus                    Chemistry     NaN        Austria
# Eric Kandel          Physiology or Medicine     NaN        Austria
# Walter Kohn                       Chemistry     NaN        Austria
#
#                                                                   text  \
# name
# Elizabeth Blackburn  Elizabeth Blackburn *, Physiology or Medicine,...
# John Cornforth                       John Cornforth *, Chemistry, 1975
# César Milstein          César Milstein *, Physiology or Medicine, 1984
# Baruj Benacerraf      Baruj Benacerraf *, Physiology or Medicine, 1980
# T. S. Eliot                            T. S. Eliot *, Literature, 1948
# ...                                                                ...
# Richard Kuhn                           Richard Kuhn *, Chemistry, 1938
# Karl von Frisch        Karl von Frisch *, Physiology or Medicine, 1973
# Martin Karplus                       Martin Karplus *, Chemistry, 2013
# Eric Kandel                Eric Kandel *, Physiology or Medicine, 2000
# Walter Kohn                             Walter Kohn *, Chemistry, 1998
#
#                          date_of_birth    date_of_death place_of_birth  \
# name
# Elizabeth Blackburn   26 November 1948              NaN         Hobart
# John Cornforth        7 September 1917  8 December 2013         Sydney
# César Milstein          8 October 1927    24 March 2002   Bahía Blanca
# Baruj Benacerraf       29 October 1920    2 August 2011        Caracas
# T. S. Eliot          26 September 1888   4 January 1965      St. Louis
# ...                                ...              ...            ...
# Richard Kuhn           3 December 1900     31 July 1967         Vienna
# Karl von Frisch       20 November 1886     12 June 1982         Vienna
# Martin Karplus           15 March 1930              NaN         Vienna
# Eric Kandel            7 November 1929              NaN         Vienna
# Walter Kohn               9 March 1923    19 April 2016         Vienna
#
#                     place_of_death  gender
# name
# Elizabeth Blackburn            NaN  female
# John Cornforth            Brighton    male
# César Milstein           Cambridge    male
# Baruj Benacerraf            Boston    male
# T. S. Eliot             Kensington    male
# ...                            ...     ...
# Richard Kuhn            Heidelberg    male
# Karl von Frisch             Munich    male
# Martin Karplus                 NaN    male
# Eric Kandel                    NaN    male
# Walter Kohn          Santa Barbara    male
#
# [138 rows x 11 columns]

# %%
df_born_in.loc['Elizabeth Blackburn']
# Out:
# link               http://en.wikipedia.org/wiki/Elizabeth_Blackburn
# year                                                           2009
# category                                     Physiology or Medicine
# country                                                         NaN
# born_in                                                   Australia
# text              Elizabeth Blackburn *, Physiology or Medicine,...
# date_of_birth                                      26 November 1948
# date_of_death                                                   NaN
# place_of_birth                                               Hobart
# place_of_death                                                  NaN
# gender                                                       female
# Name: Elizabeth Blackburn, dtype: object

# %%
def get_born_in(name):
    try:
        born_in = df_born_in.loc[name]['born_in']
        print(f'name: {name}, born in: {born_in}')
    except:
        born_in = np.nan
    return born_in

# %%
df_wbi=df_clean.copy()
df_wbi['born_in'] = df_wbi['name'].apply(get_born_in)
# Out:
# name: Luis Federico Leloir, born in: France
# name: Ivo Andrić, born in: Austria
# name: Patrick White, born in: United Kingdom
# name: Albert A. Michelson, born in: Poland
# name: Isidor Isaac Rabi, born in: Poland
# name: Otto Stern, born in: Germany
# name: William Giauque, born in: Canada
# name: Carl Ferdinand Cori, born in: Czech Republic
# name: Gerty Cori, born in: Czech Republic
# name: Polykarp Kusch, born in: Germany
# name: Fritz Albert Lipmann, born in: Germany
# name: Tsung-Dao Lee, born in: Taiwan
# name: Severo Ochoa, born in: Spain
# name: Emilio Segrè, born in: Italy
# name: Konrad Bloch, born in: Germany
# name: Maria Goeppert-Mayer, born in: Germany
# name: Har Gobind Khorana, born in: India
# name: Hans Bethe, born in: Germany
# name: Charles B. Huggins, born in: Canada
# name: Salvador Luria, born in: Italy
# name: Max Delbrück, born in: Germany
# name: George E. Palade, born in: Romania
# name: Henry Kissinger, born in: Germany
# name: Renato Dulbecco, born in: Italy
# name: Saul Bellow, born in: Canada
# name: Roger Guillemin, born in: France
# name: Andrew Schally, born in: Poland
# name: Arno Penzias, born in: Germany
# name: Allan M. Cormack, born in: South Africa
# name: Czesław Miłosz, born in: Poland
# name: Baruj Benacerraf, born in: Venezuela
# name: Isaac Bashevis Singer, born in: Poland
# name: Roald Hoffmann, born in: Poland
# name: Franco Modigliani, born in: Italy
# name: Henry Taube, born in: Canada
# name: Nicolaas Bloembergen, born in: Netherlands
# name: David H. Hubel, born in: Canada
# name: Elie Wiesel, born in: Romania
# name: Jack Steinberger, born in: Germany
# name: Hans G. Dehmelt, born in: Germany
# name: Rudolph A. Marcus, born in: Canada
# name: Sidney Altman, born in: Canada
# name: William Vickrey, born in: Canada
# name: Daniel C. Tsui, born in: China (People's Republic of China)
# name: Walter Kohn, born in: Austria
# name: Eric Kandel, born in: Austria
# name: Günter Blobel, born in: Germany
# name: Myron Scholes, born in: Canada
# name: Riccardo Giacconi, born in: Italy
# name: Sydney Brenner, born in: South Africa
# name: Anthony J. Leggett, born in: United Kingdom
# name: Alexei Alexeyevich Abrikosov, born in: Russia and Soviet Union
# name: Daniel Kahneman, born in: Israel
# name: Oliver Smithies, born in: United Kingdom
# name: Mario R. Capecchi, born in: Italy
# name: Elizabeth Blackburn, born in: Australia
# name: Venkatraman Ramakrishnan, born in: India
# name: Willard S. Boyle, born in: Canada
# name: Yoichiro Nambu, born in: Japan
# name: Leonid Hurwicz, born in: Russia and Soviet Union
# name: Michael Levitt, born in: South Africa
# name: Martin Karplus, born in: Austria
# name: Shuji Nakamura, born in: Japan
# name: John B. Goodenough, born in: Germany
# name: Abhijit Banerjee, born in: India
# name: Joachim Frank, born in: Germany
# name: Rainer Weiss, born in: Germany
# name: Syukuro Manabe, born in: Japan
# name: Ardem Patapoutian, born in: Lebanon
# name: Ernest Rutherford, born in: New Zealand
# name: George Bernard Shaw, born in: Ireland
# name: T. S. Eliot, born in: United States
# name: Ernst Boris Chain, born in: Germany
# name: Max Born, born in: Germany
# name: Hans Adolf Krebs, born in: Germany
# name: Bernard Katz, born in: Germany
# name: Nikolaas Tinbergen, born in: Netherlands
# name: John Cornforth, born in: Australia
# name: W. Arthur Lewis, born in: Saint Lucia
# name: César Milstein, born in: Argentina
# name: Aaron Klug, born in: South Africa
# name: Joseph Rotblat, born in: Poland
# name: Elias Canetti, born in: Bulgaria
# name: Christopher A. Pissarides, born in: Cyprus
# name: Konstantin Novoselov, born in: Russia and Soviet Union
# name: V. S. Naipaul, born in: Trinidad and Tobago
# name: Kazuo Ishiguro, born in: Japan
# name: Abdulrazak Gurnah, born in: Tanzania
# name: John O'Keefe, born in: United States
# name: Alfred Werner, born in: France
# name: Tadeusz Reichstein, born in: Poland
# name: Hermann Hesse, born in: Germany
# name: Nelly Sachs, born in: Germany
# name: Hans von Euler-Chelpin, born in: Germany
# name: Mario Vargas Llosa, born in: Peru
# name: Zhores Alferov, born in: Belarus
# name: Andre Geim, born in: Russia and Soviet Union
# name: Menachem Begin, born in: Russia and Soviet Union
# name: Shimon Peres, born in: Poland
# name: Seán MacBride, born in: France
# name: Robert Aumann, born in: United States
# name: Mother Teresa, born in: North Macedonia
# name: Charles K. Kao, born in: China (People's Republic of China)
# name: Wilhelm Ostwald, born in: Latvia
# name: Richard Kuhn, born in: Austria
# name: Karl von Frisch, born in: Austria
# name: Peter Grünberg, born in: Czech Republic
# name: Stefan Hell, born in: Romania
# name: Herta Müller, born in: Romania
# name: Gabriel Lippmann, born in: Luxembourg
# name: Ivan Bunin, born in: Russia and Soviet Union
# name: Albert Schweitzer, born in: Germany
# name: Georges Charpak, born in: Poland
# name: Gao Xingjian, born in: China (People's Republic of China)
# name: Emmanuelle Charpentier, born in: Germany
# name: Serge Haroche, born in: Morocco
# name: Jules A. Hoffmann, born in: Luxembourg
# name: Ben Roy Mottelson, born in: United States
# name: Niels Ryberg Finsen, born in: Faroe Islands
# name: John Macleod, born in: United Kingdom
# name: John Polanyi, born in: Germany
# name: Gerhard Herzberg, born in: Germany
# name: Michael Smith, born in: United Kingdom
# name: Christian de Duve, born in: United Kingdom
# name: Svetlana Alexievich, born in: Ukraine
# name: Bertha von Suttner, born in: Czech Republic
# name: Ilya Prigogine, born in: Russia and Soviet Union
# name: Otto Loewi, born in: Germany

# %%
df_wbi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 980 entries, 0 to 1203
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   link            980 non-null    object
#  1   name            980 non-null    object
#  2   year            980 non-null    int64
#  3   category        979 non-null    object
#  4   country         980 non-null    object
#  5   text            980 non-null    object
#  6   date_of_birth   980 non-null    datetime64[ns]
#  7   date_of_death   680 non-null    datetime64[ns]
#  8   place_of_birth  980 non-null    object
#  9   place_of_death  677 non-null    object
#  10  gender          980 non-null    object
#  11  award_age       980 non-null    int64
#  12  born_in         128 non-null    object
# dtypes: datetime64[ns](2), int64(2), object(9)
# memory usage: 107.2+ KB

# %%
# this won't work with duplicate names in our index
# df_wbi['born_in'] = df_born_in.born_in

# %%
df_wbi.count()
# Out:
# link              980
# name              980
# year              980
# category          979
# country           980
# text              980
# date_of_birth     980
# date_of_death     680
# place_of_birth    980
# place_of_death    677
# gender            980
# award_age         980
# born_in           128
# dtype: int64

# %%
# Merging DataFrames
df_winners_bios = pd.read_json(open('data/scrapy_nwinners_minibio.json'))
df_clean_bios = pd.merge(df_wbi,df_winners_bios,how='outer',on='link')

# %%
df_clean_bios.count()
# Out:
# link              994
# name              980
# year              980
# category          979
# country           980
# text              980
# date_of_birth     980
# date_of_death     680
# place_of_birth    980
# place_of_death    677
# gender            980
# award_age         980
# born_in           128
# image_urls        474
# mini_bio          474
# bio_image         474
# dtype: int64

# %%
df_clean_bios = df_clean_bios[~df_clean_bios.name.isnull()].drop_duplicates(subset=['link','year'])

# %%
df_clean_bios.count()
# Out:
# link              971
# name              971
# year              971
# category          970
# country           971
# text              971
# date_of_birth     971
# date_of_death     673
# place_of_birth    971
# place_of_death    670
# gender            971
# award_age         971
# born_in           127
# image_urls        451
# mini_bio          451
# bio_image         451
# dtype: int64

# %%
df_clean_bios[df_clean_bios.mini_bio.isnull()]
# Out:
#                                                   link                 name  \
# 17   http://en.wikipedia.org/wiki/L%C3%AA_%C4%90%E1...           Lê Đức Thọ
# 18     http://en.wikipedia.org/wiki/Theodore_Roosevelt   Theodore Roosevelt
# 19        http://en.wikipedia.org/wiki/Tawakkol_Karman      Tawakkol Karman
# 20    http://en.wikipedia.org/wiki/Albert_A._Michelson  Albert A. Michelson
# 21             http://en.wikipedia.org/wiki/Elihu_Root           Elihu Root
# ..                                                 ...                  ...
# 628           http://en.wikipedia.org/wiki/Maria_Ressa          Maria Ressa
# 629        http://en.wikipedia.org/wiki/Olga_Tokarczuk       Olga Tokarczuk
# 630  http://en.wikipedia.org/wiki/Wis%C5%82awa_Szym...   Wisława Szymborska
# 646         http://en.wikipedia.org/wiki/Yasser_Arafat        Yasser Arafat
# 834      http://en.wikipedia.org/wiki/Klaus_Hasselmann     Klaus Hasselmann
#
#        year    category        country  \
# 17   1973.0       Peace        Vietnam
# 18   1906.0       Peace  United States
# 19   2011.0       Peace          Yemen
# 20   1907.0     Physics  United States
# 21   1912.0       Peace  United States
# ..      ...         ...            ...
# 628  2021.0       Peace    Philippines
# 629  2018.0  Literature         Poland
# 630  1996.0  Literature         Poland
# 646  1994.0       Peace      Palestine
# 834  2021.0     Physics        Germany
#
#                                                   text date_of_birth  \
# 17   Lê Đức Thọ ,  born in French Indochina , Peace...    1911-10-14
# 18                    Theodore Roosevelt , Peace, 1906    1858-10-27
# 19                       Tawakkol Karman , Peace, 2011    1979-02-07
# 20   Albert A. Michelson ,  born in then Germany, n...    1852-12-19
# 21                            Elihu Root , Peace, 1912    1845-02-15
# ..                                                 ...           ...
# 628                          Maria Ressa , Peace, 2021    1963-10-02
# 629                  Olga Tokarczuk , Literature, 2018    1962-01-29
# 630              Wisława Szymborska , Literature, 1996    1923-07-02
# 646  Yasser Arafat ,  Born in Cairo, Egypt , Peace,...    1929-08-04
# 834                   Klaus Hasselmann , Physics, 2021    1931-10-25
#
#     date_of_death place_of_birth place_of_death  gender  award_age born_in  \
# 17     1990-10-13         Hà Nam          Hanoi    male       62.0     NaN
# 18     1919-01-06  New York City  Sagamore Hill    male       48.0     NaN
# 19            NaT         Ta'izz            NaN  female       32.0     NaN
# 20     1931-05-09       Strzelno       Pasadena    male       55.0  Poland
# 21     1937-02-07        Clinton  New York City    male       67.0     NaN
# ..            ...            ...            ...     ...        ...     ...
# 628           NaT         Manila            NaN  female       58.0     NaN
# 629           NaT       Sulechów            NaN  female       56.0     NaN
# 630    2012-02-01         Kórnik         Kraków  female       73.0     NaN
# 646    2004-11-11          Cairo        Clamart    male       65.0     NaN
# 834           NaT        Hamburg            NaN    male       90.0     NaN
#
#     image_urls mini_bio bio_image
# 17         NaN      NaN       NaN
# 18         NaN      NaN       NaN
# 19         NaN      NaN       NaN
# 20         NaN      NaN       NaN
# 21         NaN      NaN       NaN
# ..         ...      ...       ...
# 628        NaN      NaN       NaN
# 629        NaN      NaN       NaN
# 630        NaN      NaN       NaN
# 646        NaN      NaN       NaN
# 834        NaN      NaN       NaN
#
# [520 rows x 16 columns]

# %%
df_clean_bios.drop('image_urls', axis=1, inplace=True)
df_clean_bios.count()
# Out:
# link              971
# name              971
# year              971
# category          970
# country           971
# text              971
# date_of_birth     971
# date_of_death     673
# place_of_birth    971
# place_of_death    670
# gender            971
# award_age         971
# born_in           127
# mini_bio          451
# bio_image         451
# dtype: int64

# %%
df_clean_bios.to_json('data/nobel_winners_cleaned.json',orient='records',date_format='iso')

# %%
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import create_engine, Column, Integer, String, Enum
import psycopg2

db_params = {
    "dbname": "postgres",
    "user": "filipe",
    "password": "mysecretword123",
    "host": "localhost",
    "port": "5432",
}

new_db_name = "nobel_winners_chapter_nine"


# def create_database(dbname):
#     try:
#         conn = psycopg2.connect(
#             dbname=db_params["dbname"],
#             user=db_params["user"],
#             password=db_params["password"],
#             host=db_params["host"],
#         )
#         conn.autocommit = True
#         cursor = conn.cursor()
#         cursor.execute(f"CREATE DATABASE {dbname}")
#         cursor.close()
#         conn.close()
#         print(f"Database {new_db_name} created successfully.")
#     except Exception as e:
#         print(f"Failed to create database: {e}")


# create_database(new_db_name)

engine = create_engine(
    f'postgresql+psycopg2://{db_params["user"]}:{db_params["password"]}@{db_params["host"]}:{db_params["port"]}/{new_db_name}'
)


# df_clean_bios.to_sql("winners", engine, if_exists="replace")

# %%
import pandas as pd
df_read_sql = pd.read_sql('winners',engine)
df_read_sql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           971 non-null    int64
#  1   link            971 non-null    object
#  2   name            971 non-null    object
#  3   year            971 non-null    float64
#  4   category        970 non-null    object
#  5   country         971 non-null    object
#  6   text            971 non-null    object
#  7   date_of_birth   971 non-null    datetime64[ns]
#  8   date_of_death   673 non-null    datetime64[ns]
#  9   place_of_birth  971 non-null    object
#  10  place_of_death  670 non-null    object
#  11  gender          971 non-null    object
#  12  award_age       971 non-null    float64
#  13  born_in         127 non-null    object
#  14  mini_bio        451 non-null    object
#  15  bio_image       451 non-null    object
# dtypes: datetime64[ns](2), float64(2), int64(1), object(11)
# memory usage: 121.5+ KB

# %%
pd.read_sql_query("SELECT * FROM winners WHERE country='Japan'", engine)
# Out:
#     index                                               link  \
# 0     672  http://en.wikipedia.org/wiki/Kenzabur%C5%8D_%C...
# 1     673       http://en.wikipedia.org/wiki/Susumu_Tonegawa
# 2     674         http://en.wikipedia.org/wiki/Kenichi_Fukui
# 3     675      http://en.wikipedia.org/wiki/Eisaku_Sat%C5%8D
# 4     676             http://en.wikipedia.org/wiki/Leo_Esaki
# 5     677         http://en.wikipedia.org/wiki/Koichi_Tanaka
# 6     678     http://en.wikipedia.org/wiki/Masatoshi_Koshiba
# 7     679     http://en.wikipedia.org/wiki/Toshihide_Maskawa
# 8     680  http://en.wikipedia.org/wiki/Makoto_Kobayashi_...
# 9     681       http://en.wikipedia.org/wiki/Shinya_Yamanaka
# 10    682  http://en.wikipedia.org/wiki/Akira_Suzuki_(che...
# 11    683         http://en.wikipedia.org/wiki/Hiroshi_Amano
# 12    684         http://en.wikipedia.org/wiki/Isamu_Akasaki
# 13    685       http://en.wikipedia.org/wiki/Ei-ichi_Negishi
# 14    686       http://en.wikipedia.org/wiki/Osamu_Shimomura
# 15    687     http://en.wikipedia.org/wiki/Ry%C5%8Dji_Noyori
# 16    688      http://en.wikipedia.org/wiki/Hideki_Shirakawa
# 17    689     http://en.wikipedia.org/wiki/Yasunari_Kawabata
# 18    690    http://en.wikipedia.org/wiki/Sin-Itiro_Tomonaga
# 19    691         http://en.wikipedia.org/wiki/Hideki_Yukawa
# 20    693        http://en.wikipedia.org/wiki/Takaaki_Kajita
# 21    694    http://en.wikipedia.org/wiki/Satoshi_%C5%8Cmura
# 22    695      http://en.wikipedia.org/wiki/Yoshinori_Ohsumi
# 23    696          http://en.wikipedia.org/wiki/Tasuku_Honjo
# 24    706         http://en.wikipedia.org/wiki/Akira_Yoshino
#
#                   name    year                category country  \
# 0         Kenzaburō Ōe  1994.0              Literature   Japan
# 1      Susumu Tonegawa  1987.0  Physiology or Medicine   Japan
# 2        Kenichi Fukui  1981.0               Chemistry   Japan
# 3          Eisaku Satō  1974.0                   Peace   Japan
# 4            Leo Esaki  1973.0                 Physics   Japan
# 5        Koichi Tanaka  2002.0               Chemistry   Japan
# 6    Masatoshi Koshiba  2002.0                 Physics   Japan
# 7    Toshihide Maskawa  2008.0                 Physics   Japan
# 8     Makoto Kobayashi  2008.0                 Physics   Japan
# 9      Shinya Yamanaka  2012.0  Physiology or Medicine   Japan
# 10        Akira Suzuki  2010.0               Chemistry   Japan
# 11       Hiroshi Amano  2014.0                 Physics   Japan
# 12       Isamu Akasaki  2014.0                 Physics   Japan
# 13     Ei-ichi Negishi  2010.0               Chemistry   Japan
# 14     Osamu Shimomura  2008.0               Chemistry   Japan
# 15        Ryōji Noyori  2001.0               Chemistry   Japan
# 16    Hideki Shirakawa  2000.0               Chemistry   Japan
# 17   Yasunari Kawabata  1968.0              Literature   Japan
# 18  Sin-Itiro Tomonaga  1965.0                 Physics   Japan
# 19       Hideki Yukawa  1949.0                 Physics   Japan
# 20      Takaaki Kajita  2015.0                 Physics   Japan
# 21       Satoshi Ōmura  2015.0  Physiology or Medicine   Japan
# 22    Yoshinori Ohsumi  2016.0  Physiology or Medicine   Japan
# 23        Tasuku Honjo  2018.0  Physiology or Medicine   Japan
# 24       Akira Yoshino  2019.0               Chemistry   Japan
#
#                                                  text date_of_birth  \
# 0                     Kenzaburō Ōe , Literature, 1994    1935-01-31
# 1      Susumu Tonegawa , Physiology or Medicine, 1987    1939-09-06
# 2                     Kenichi Fukui , Chemistry, 1981    1918-10-04
# 3                           Eisaku Satō , Peace, 1974    1901-03-27
# 4                           Leo Esaki , Physics, 1973    1925-03-12
# 5                     Koichi Tanaka , Chemistry, 2002    1959-08-03
# 6                   Masatoshi Koshiba , Physics, 2002    1926-09-19
# 7                   Toshihide Maskawa , Physics, 2008    1940-02-07
# 8                    Makoto Kobayashi , Physics, 2008    1944-04-07
# 9      Shinya Yamanaka , Physiology or Medicine, 2012    1962-09-04
# 10                     Akira Suzuki , Chemistry, 2010    1930-09-12
# 11                      Hiroshi Amano , Physics, 2014    1960-09-11
# 12                      Isamu Akasaki , Physics, 2014    1929-01-30
# 13  Ei-ichi Negishi ,  Born in China , Chemistry, ...    1935-07-14
# 14                  Osamu Shimomura , Chemistry, 2008    1928-08-27
# 15                     Ryōji Noyori , Chemistry, 2001    1938-09-03
# 16                 Hideki Shirakawa , Chemistry, 2000    1936-08-20
# 17               Yasunari Kawabata , Literature, 1968    1899-06-11
# 18                 Sin-Itiro Tomonaga , Physics, 1965    1906-03-31
# 19                      Hideki Yukawa , Physics, 1949    1907-01-23
# 20                     Takaaki Kajita , Physics, 2015    1959-03-09
# 21       Satoshi Ōmura , Physiology or Medicine, 2015    1935-07-12
# 22    Yoshinori Ohsumi , Physiology or Medicine, 2016    1945-02-09
# 23        Tasuku Honjo , Physiology or Medicine, 2018    1942-01-27
# 24                    Akira Yoshino , Chemistry, 2019    1948-01-30
#
#    date_of_death    place_of_birth                 place_of_death gender  \
# 0     2023-03-03               Ōse                           None   male
# 1            NaT            Nagoya                           None   male
# 2     1998-01-09             Heijō                          Kyoto   male
# 3     1975-06-03            Tabuse  The Jikei University Hospital   male
# 4            NaT           Takaida                           None   male
# 5            NaT            Toyama                           None   male
# 6     2020-11-12         Toyohashi                          Tokyo   male
# 7     2021-07-23            Nagoya                          Kyoto   male
# 8            NaT            Nagoya                           None   male
# 9            NaT           Hiraoka                           None   male
# 10           NaT            Mukawa                           None   male
# 11           NaT         Hamamatsu                           None   male
# 12    2021-04-01            Chiran                         Nagoya   male
# 13    2021-06-06          Hsinking                   Indianapolis   male
# 14    2018-10-19       Fukuchiyama                       Nagasaki   male
# 15           NaT            Ashiya                           None   male
# 16           NaT             Tokyo                           None   male
# 17    1972-04-16             Osaka                          Zushi   male
# 18    1979-07-08             Tokyo                          Tokyo   male
# 19    1981-09-08             Azabu                          Kyoto   male
# 20           NaT  Higashimatsuyama                           None   male
# 21           NaT          Kamiyama                           None   male
# 22           NaT           Fukuoka                           None   male
# 23           NaT             Kyoto                           None   male
# 24           NaT             Suita                           None   male
#
#     award_age born_in                                           mini_bio  \
# 0        59.0    None  <p><b>Kenzaburō Ōe</b><span style="font-weight...
# 1        48.0    None  <p><b>Susumu Tonegawa</b><span style="font-wei...
# 2        63.0    None  <p><b>Kenichi Fukui</b><span style="font-weigh...
# 3        73.0    None  <p><b>Eisaku Satō</b><span style="font-weight:...
# 4        48.0    None  <p><b>Reona Esaki</b> (江崎 玲於奈 <i>Esaki Reona</...
# 5        43.0    None  <p><b>Koichi Tanaka</b><span style="font-weigh...
# 6        76.0    None  <p><b>Masatoshi Koshiba</b><span style="font-w...
# 7        68.0    None  <p><b>Toshihide Maskawa</b> (or <b>Masukawa</b...
# 8        64.0    None  <p><b>Makoto Kobayashi</b><span style="font-we...
# 9        50.0    None  <p class="mw-empty-elt">\n</p><p><b>Shinya Yam...
# 10       80.0    None  <p><b>Akira Suzuki</b><span style="font-weight...
# 11       54.0    None  <p><b>Hiroshi Amano</b><span style="font-weigh...
# 12       85.0    None  <p><b>Isamu Akasaki</b><span style="font-weigh...
# 13       75.0    None  <p><b>Ei-ichi Negishi</b><span style="font-wei...
# 14       80.0    None  <p><b>Osamu Shimomura</b><span style="font-wei...
# 15       63.0    None  <p><b>Ryōji Noyori</b><span style="font-weight...
# 16       64.0    None  <p><b>Hideki Shirakawa</b><span style="font-we...
# 17       69.0    None  <p class="mw-empty-elt">\n</p><p><b>Yasunari K...
# 18       59.0    None  <p><b>Shinichiro Tomonaga</b><sup id="cite_ref...
# 19       42.0    None  <p><b>Hideki Yukawa</b> <span class="noexcerpt...
# 20       56.0    None  <p><b>Takaaki Kajita</b><span style="font-weig...
# 21       80.0    None  <p><b>Satoshi Ōmura</b><span style="font-weigh...
# 22       71.0    None  <p><b>Yoshinori Ohsumi</b><span style="font-we...
# 23       76.0    None  <p><b>Tasuku Honjo</b><span style="font-weight...
# 24       71.0    None  <p class="mw-empty-elt">\n</p><p><b>Akira Yosh...
#
#                                             bio_image
# 0   full/c5f9e6e90e966894382236c6c5ea303dca36a51f.jpg
# 1   full/8d4dab9c2934a5b2129c195b955cbdf7bbd8dd3c.jpg
# 2   full/3f29c98b15436c1477b6d7bcf893e9d20788c32f.jpg
# 3   full/f66a21f02883747b2689a30bb09147a4de729c6a.jpg
# 4   full/5709d3674213e9d3a1b6846ff95606e65a41c860.jpg
# 5   full/632f4321d20c3bfddd8cfb4f9d00d8744d032859.jpg
# 6   full/3f5e3ae23987c94e682b1527728ec4c4ef048047.jpg
# 7   full/3e4321f1022a1478ee2ffbdfc0680d722c3a6441.jpg
# 8   full/945a31a0afd2e821513e0d676dfa251f4605c1e5.jpg
# 9   full/10191526d8d3d5183017fd0416c16911eebcfde3.jpg
# 10  full/4f93729ec22ed121f699aef23ec2ab59164d93a7.jpg
# 11  full/ad236f8070ad9c6e1dc3b35e97acd66966259f84.jpg
# 12  full/c85f5bfaba3a43ca89c128de0a1b7e3dd7af3cc0.jpg
# 13  full/acd8b2fe4e70d0edb4bb0143b813f26abf93f94c.jpg
# 14  full/d0c65a29be8597856800595a2dd6e9cd10c3023a.jpg
# 15  full/498130a3be3cf536b839f1c3d159650ac0ea802a.jpg
# 16  full/76126fe59a788b04a61bf540f8c1aee41998b900.jpg
# 17  full/95783582ebf52f512304ccb8ed7ff11d17707303.jpg
# 18  full/4858fa0e8efde0bba6165da5ac20b613021389cc.jpg
# 19  full/ff3c49f547a82ce7e2f2234c3856edc841be0e59.jpg
# 20  full/ae07da1aaaac9823141e55587a3f3f0483df69f6.jpg
# 21  full/8efb2a6027e4fce7e1a0f16856b06da77ec33576.jpg
# 22  full/e11d19e57623f7a1f4379befba70a89b636d61d5.jpg
# 23  full/2c15462a388957c0f11299b1fffabb7da1d5c9f4.jpg
# 24  full/7d6f6c16a4698051cf31c58d2fdb5819ec945b89.jpg
